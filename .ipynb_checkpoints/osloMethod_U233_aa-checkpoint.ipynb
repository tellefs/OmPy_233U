# %% [markdown]
# Import useful programs

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import ompy as om
import logging

import scipy as sp
#%matplotlib widget
from ipywidgets import widgets #interact, interactive, fixed, interact_manual

from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
om.__full_version__;

# %%
# For reproducability we seed the random generator.
# Note that by default several other classes in ompy, such as all
# classes with multinest calculations have a default seed, too
np.random.seed(1382398)

# %%
# get smaller files for the online version
plt.rcParams["figure.dpi"] = 80

# %%
major_tick_length=12
minor_tick_length=5
tick_width=2
tick_labelsize=22
label_fontsize=22
title_fontsize=22
figwidth=10
figheigth=8
save_dpi = 100


def plot_3D(matrix, filename, xlabel='xlabel', ylabel='ylabel'):
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    matrix.plot(ax=ax);
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(axis='both', which='both', labelsize=tick_labelsize, width=tick_width)
    ax.tick_params(axis='both', which='major', length=major_tick_length)
    ax.tick_params(axis='both', which='minor', length=minor_tick_length)
    ax.set_xlabel(xlabel,fontsize=label_fontsize)
    ax.set_ylabel(ylabel,fontsize=label_fontsize)
    fig.axes[1].tick_params(labelsize=tick_labelsize)
    ax.grid(color='k', linestyle='--', linewidth=.5)
    fig.savefig(filename, dpi=save_dpi)
    
def plot_2D(matrix, filename, projection_axis, xlabel='xlabel', ylabel='ylabel', yscale='log'):
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    matrix.plot_projection(projection_axis, kind="step", ax=ax);
    plt.yscale(yscale)
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(axis='both', which='both', labelsize=tick_labelsize, width=tick_width)
    ax.tick_params(axis='both', which='major', length=major_tick_length)
    ax.tick_params(axis='both', which='minor', length=minor_tick_length)
    ax.set_xlabel(xlabel,fontsize=label_fontsize)
    ax.set_ylabel(ylabel,fontsize=label_fontsize)
    ax.grid(color='k', linestyle='--', linewidth=.5)
    fig.savefig(filename, dpi=save_dpi)

# %%
def plot_matrix(matrix, fig_name, title, scale='log', x_label='$\gamma$-ray energy $E_\gamma$', ylabel='Excitation energy $E_x$'):
    fig, ax = plt.subplots(figsize=(10, 8))
    matrix.plot(ax=ax, scale=scale);
    ax.tick_params(axis='both', labelsize=18)
    ax.set_xlabel('$\gamma$-ray energy $E_\gamma$',fontsize=18)
    ax.set_ylabel('Excitation energy $E_x$',fontsize=18)
    ax.set_title(None)
    fig.suptitle(title, fontsize=20)
    fig.axes[1].tick_params(labelsize=18)
    fig.savefig(fig_name)

# %%
# Import raw matrix into instance of om.Matrix()
#raw = om.Matrix(path="alfna_matrix/alfna_U233")
raw = om.Matrix(path="alfna_matrix/alfna_right_bg_timecuts")
raw_fiss = om.Matrix(path="alfna_matrix/alfna_fiss_right_bg_timecuts")

#Rebin matrices
raw.rebin(0,factor=12)
raw.rebin(1,factor=12)
raw_fiss.rebin(0,factor=12)
raw_fiss.rebin(1,factor=12)

# %%
#plot raw matrix
raw_plot_big = raw.copy()
raw_plot_big.cut('Ex', 0, 8000)
raw_plot_big.cut('Eg', 0, 6000)

Ex = raw_plot_big.Ex
Eg = raw_plot_big.Eg

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
raw_plot_big.plot(ax=ax, vmin=1e-1, vmax=1e2);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot(Eg, Eg, "r--", label="E_x = E_g", linewidth=3.0);
fig.axes[1].tick_params(labelsize=tick_labelsize)

#Plot new diagonal to be used for calibration

#Linefit to calibrate Ex

#finding calibration points alog the diagonal
p0 = [0,0]
p1 = [500, 700]
p2 = [1000, 1200]
p3 = [1500, 1800]
p4 = [2000, 2300]
p5 = [2350, 2600]

#linefit
y_linefit = np.asarray([p0[1], p1[1], p2[1], p3[1], p4[1], p5[1]])
x_linefit = np.asarray([p0[0], p1[0], p2[0], p3[0], p4[0], p5[0]])
z = np.polyfit(x_linefit, y_linefit, 1)
poly = np.poly1d(z)
new_diag = Eg*poly[1] + poly[0]
ax.plot(Eg, new_diag, 'r--', linewidth=3.0);

#finding calibration points alog the diagonal
ax.plot(p0[0], p0[1], 'ko', markersize=7.0);
ax.plot(p1[0], p1[1], 'ko', markersize=7.0);
ax.plot(p2[0], p2[1], 'ko', markersize=7.0);
ax.plot(p3[0], p3[1], 'ko', markersize=7.0);
ax.plot(p4[0], p4[1], 'ko', markersize=7.0);
ax.plot(p5[0], p5[1], 'ko', markersize=7.0);



fig.savefig('plots/raw_uncalibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 1800], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 1800], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=label_fontsize, loc='upper left');
fig.savefig('plots/Ex_py_uncalibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw_fiss.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 200], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 200], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=label_fontsize, loc='upper left');
fig.savefig('plots/Ex_py_fiss_uncalibrated', dpi=save_dpi)

# %%
#Calibrate Ex to new diagonal which is decided here
new_diag = raw.Ex*poly[1] + poly[0]
raw.Ex = 2*raw.Ex - new_diag
raw_fiss.Ex = 2*raw_fiss.Ex - new_diag

# %%
#plot raw matrix after calibration

raw_plot_big = raw.copy()
raw_plot_big.cut('Ex', 0, 8000)
raw_plot_big.cut('Eg', 0, 6000)


fig, ax = plt.subplots(figsize=(figwidth, figheigth))
raw_plot_big.plot(ax=ax, vmin=1e-1, vmax=1e2);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
x = np.linspace(0, 6000, len(raw.Ex))
ax.plot(x, x, "r--", label="E_x = E_g", linewidth=3.0);
#ax.plot(x, np.ones(len(raw.Ex))*5550, 'r--'); #fission barrier
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/raw_calibrated', dpi=save_dpi)

#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 1300], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 1300], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=16, loc='upper right');
fig.savefig('plots/Ex_py_calibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw_fiss.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 150], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 150], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=16, loc='upper right');
fig.savefig('plots/Ex_py_fiss_calibrated', dpi=save_dpi)

# %%
#Rebin raw matrix

def rebin_raw(raw, kev_per_bin_wish, keep=False):
    raw_rebin = raw.copy()
    raw_rebin.cut('Ex', 0, 10000)
    raw_rebin.cut('Eg', 0, 10000)
    kev_per_bin = abs(raw_rebin.Eg[0]-raw_rebin.Eg[1])
    rebin_factor = kev_per_bin_wish/kev_per_bin
    raw_rebin.rebin('Ex', factor=rebin_factor) #rebinning the Eg energy axis
    raw_rebin.rebin('Eg', factor=rebin_factor) #rebinning the Ex energy axis

    #plot matrix
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    raw_rebin.plot(ax=ax, vmin=1e-1, vmax=1e3);
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(axis='both', which='both', labelsize=tick_labelsize, width=tick_width)
    ax.tick_params(axis='both', which='major', length=major_tick_length)
    ax.tick_params(axis='both', which='minor', length=minor_tick_length)
    ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
    ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
    fig.axes[1].tick_params(labelsize=tick_labelsize)
    ax.grid(color='k', linestyle='--', linewidth=.5)
    fig.savefig('plots/rebinned_matrix', dpi=save_dpi)
    if keep==True:
        raw.rebin('Ex', factor=rebin_factor)
        raw.rebin('Eg', factor=rebin_factor)
        
rebin_raw(raw, kev_per_bin_wish=128.*2, keep=True)

# %%
# Cut away counts above (below?) the diagonal
# Remember: Think about what you do here. If you cut them away, they will not
# be used in unfolding etc. This may or may not be what you want.

raw_cut = raw.copy()

raw_cut.cut_diagonal(E1=(200, 0), E2=(7700, 7500))
raw_cut.cut('Ex', 0, 6000)
raw_cut.cut('Eg', 0, 6000)

fig, ax = plt.subplots(figsize=(10, 8))
raw_cut.plot(ax=ax, scale='log', vmin=1e-1, vmax=1e3);
ax.tick_params(axis='both', labelsize=18)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$',fontsize=18)
ax.set_ylabel('Excitation energy $E_x$',fontsize=18)
ax.set_title(None)
fig.suptitle('Raw matrix after calibrations and diagonal cut', fontsize=20)
fig.axes[1].tick_params(labelsize=18)
fig.savefig('plots/raw_diag_cut')

raw = raw_cut

# %% [markdown]
# From the GettingStarted OmPy manual: "Eventhough this experiment was performed with CACTUS, we will now give an example as if the data was taken with OSCAR. This is beacause it is slightly easier to handle. For CACTUS, the response functions do not include the detector threshold; this has do be taken into account separately."
#
# So, I need to include the detector threshold for CACTUS

# %%
### GETTING RESPONSE MATRIX


logger = om.introspection.get_logger('response', 'INFO')
# Then do the same using OMpy functionality:
# You may need to adpot this to whereever you response matrixes are stored
folderpath = "../OCL_response_functions/nai2012_for_opt13"

# Energy calibration of resulting response matrix:
Eg = raw.Eg

# Experimental relative FWHM at 1.33 MeV of resulting array
#fwhm_abs = 30 # (30/1330 = 2.25% ) #LaBr
fwhm_abs = 90.44 # (90/1330 = 6.8%) #CACTUS


response = om.Response(folderpath)
R_ompy_view, R_tab_view = response.interpolate(Eg, fwhm_abs=fwhm_abs, return_table=True)
# Magne recommends 1/10 of the actual resolution for unfolding purposes (see article)
R_ompy_unf, R_tab_unf = response.interpolate(Eg, fwhm_abs=fwhm_abs/10, return_table=True)

R_ompy_view.save("R_ompy_view.m")
R_ompy_unf.save("R_ompy_unf.m")
R_tab_view.to_pickle("R_tab_view.pkl")
R_tab_unf.to_pickle("R_tab_unf.pkl")
# Out:
# 2020-09-28 10:20:56,517 - ompy.response - INFO - Note: Spectra outside of 360.0 and 15000.0 are extrapolation only.
# 2020-09-28 10:20:56,640 - ompy.response - INFO - Note: Spectra outside of 360.0 and 15000.0 are extrapolation only.

# %%
# adding response function for CACTUS

fthreshold = sp.interpolate.interp1d([30., 80., 122., 183., 244., 294., 344., 562., 779., 1000.],
                      [0.0, 0.0, 0.0, 0.06, 0.44, 0.60, 0.87, 0.99, 1.00, 1.00],
                      fill_value="extrapolate") #from mama-software ('folding.f')

def apply_detector_threshold(response, table, fthreshold):
    thres = fthreshold(response.Eg)
    response.values = response.values * thres
    # renormalize
    response.values = om.div0(response.values, response.values.sum(axis=1)[:, np.newaxis])
    table["eff_tot"] *= thres

apply_detector_threshold(R_ompy_unf, R_tab_unf, fthreshold)
apply_detector_threshold(R_ompy_view, R_tab_view, fthreshold)


fig, ax = plt.subplots(figsize=(figwidth, figheigth))
R_ompy_view.plot(ax=ax, scale="log", vmin=1e-5, vmax=1e0);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Response Matrix', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/response_matrix', dpi=save_dpi)

# %%
### UNFOLDING

# You can decide to log information and set the logging level (info/debug)
logger = om.introspection.get_logger('unfolder', 'INFO')

# We need to remove negative counts (unphysical) in the raw matrix before unfolding:
raw_positive = raw.copy()
raw_positive.fill_and_remove_negative(window_size=20)
plot_matrix(raw_positive, 'plots/raw_positive_matrix', title='Raw positive matrix')

# With compton subtraction and all tweaks
unfolder = om.Unfolder(response=R_ompy_unf)
unfolder.use_compton_subtraction = True # default
unfolder.response_tab = R_tab_unf
# Magne suggests some "tweaks" for a better unfolding performance. Default is 1 for all.
unfolder.FWHM_tweak_multiplier = {"fe": 1., "se": 1.1,
                                     "de": 1.3, "511": 0.9} #SJEKK DETTE
unfolded = unfolder(raw_positive)

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
unfolded.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e3);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Unfolded', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/unfolded_matrix', dpi=save_dpi)

# %%
### Generate the first generation matrix

firstgen = om.FirstGeneration()
primary = firstgen(unfolded)

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
primary.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e3);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Primary', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/firstgen_matrix', dpi=save_dpi)

# %%
### Propagating statistical uncertainties

logger = om.introspection.get_logger('ensemble', 'INFO')

# Tell the `Ensemble` class which raw spectrum, what kind of unfolder and first
# generations method to use.
# Note: This will have the same setting as above. We could for example have
# set the first generations method to use a different "valley_collection", or a
# differnt type of "multiplicity_estimation"
ensemble = om.Ensemble(raw=raw_positive)
ensemble.unfolder = unfolder
ensemble.first_generation_method = firstgen
# Generates N perturbated members; here just 10 to speed it up
# the `regenerate` flag ensures, that we don't load from disk; which might result in expected results
# if we have changed something in the input `raw` matrix.
ensemble.generate(10, regenerate=True)
# Out:
# 2020-09-28 10:20:59,356 - ompy.ensemble - INFO - Start normalization with 3 cpus
# 2020-09-28 10:20:59,419 - ompy.ensemble - INFO - Generating/loading 0
# 2020-09-28 10:20:59,455 - ompy.ensemble - INFO - Generating/loading 1
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 2020-09-28 10:20:59,481 - ompy.ensemble - INFO - Generating/loading 2
# 2020-09-28 10:20:59,587 - ompy.ensemble - INFO - Generating/loading 3
# 2020-09-28 10:20:59,588 - ompy.ensemble - INFO - Generating/loading 4
# 2020-09-28 10:20:59,605 - ompy.ensemble - INFO - Generating/loading 5
# 2020-09-28 10:20:59,713 - ompy.ensemble - INFO - Generating/loading 6
# 2020-09-28 10:20:59,713 - ompy.ensemble - INFO - Generating/loading 7
# 2020-09-28 10:20:59,734 - ompy.ensemble - INFO - Generating/loading 8
# 2020-09-28 10:20:59,833 - ompy.ensemble - INFO - Generating/loading 9

# %%
#old plotting of unfolded and ensemble
#i_unfolded = 9
#matrix = ensemble.get_unfolded(i_unfolded)
#matrix.plot(title=f"Unfolded matrix #{i_unfolded}")

# Following commands plots all std. deviations
#ensemble.plot();

# %% [markdown]
# Extract Nuclear level density and gamma strength function

# %%
extlog = om.introspection.get_logger('extractor', 'INFO')
trapezoid_cut = om.Action('matrix')
# Trapezoidal cuts
Ex_min = 2000
Ex_max = 5300
Eg_min = 1000
Eg_max = 6000

def plot_primary_w_trapez(primary, Ex_min, Ex_max, Eg_min, Eg_max, save=False):
    #plot primary matrix with trapezoidal cuts:
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    primary.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e3);
    ax.tick_params(axis='both', labelsize=tick_labelsize)
    ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
    ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
    # Trapez
    x = [Eg_min, Ex_min+200, Ex_max+200, Eg_min]
    y = [Ex_min, Ex_min, Ex_max, Ex_max]
    textstr = '\n'.join((
        r'$E_{x, min}=%.0f$' % (Ex_min, ),
        r'$E_{x, max}=%.0f$' % (Ex_max, ),
        r'$E_{\gamma, min}=%.0f$' % (Eg_min, ),
        r'$E_{\gamma, max}=%.0f$' % (Eg_max, )))
    # these are matplotlib.patch.Patch properties
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    # place a text box in upper left in axes coords
    ax.text(.70, 0.25, textstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)

    ax.add_patch(patches.Polygon(xy=list(zip(x,y)), fill=False, linewidth=3.0, color='r', linestyle='--'))
    fig.axes[1].tick_params(labelsize=tick_labelsize)
    if(save==True):
        fig.savefig('plots/firstgen_trapezoid', dpi=save_dpi)

# %%
plot_primary_w_trapez(primary, Ex_min, Ex_max, Eg_min, Eg_max)
trapezoid_cut.trapezoid(Ex_min=Ex_min, Ex_max=Ex_max, Eg_min=Eg_min, inplace=True)
extractor = om.Extractor()
extractor.trapezoid = trapezoid_cut


#E_rebinned = np.arange(0, 6500, 200.) #RIKTIG BINNING?
E_rebinned = ensemble.get_firstgen(0).Ex
ensemble.rebin(E_rebinned, member="firstgen")
extractor.extract_from(ensemble, regenerate=True)

extractor.plot(scale='log', plot_mean=False);
plt.savefig('unnormed_new_falsemean')
extractor.plot(scale='log', plot_mean=True);
plt.savefig('unnormed_new_truemean')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-255-9c01d6ad4b4d> in <module>
#       8 E_rebinned = ensemble.get_firstgen(0).Ex
#       9 ensemble.rebin(E_rebinned, member="firstgen")
# ---> 10 extractor.extract_from(ensemble, regenerate=True)
#      11
#      12 extractor.plot(scale='log', plot_mean=False);
#
# ~/ompy/ompy/extractor.py in extract_from(self, ensemble, trapezoid, regenerate)
#     145                 gsfs.append(Vector(path=gsf_path))
#     146             else:
# --> 147                 nld, gsf = self.step(i)
#     148                 nld.save(nld_path)
#     149                 gsf.save(gsf_path)
#
# ~/ompy/ompy/extractor.py in step(self, num)
#     160             num: Number of the fg matrix to extract
#     161         """
# --> 162         nld, gsf = self._extract(num)
#     163         return nld, gsf
#     164
#
# ~/ompy/ompy/extractor.py in _extract(self, num)
#     186             self.trapezoid.act_on(matrix)
#     187             self.trapezoid.act_on(std)
# --> 188         nld, gsf = self.decompose(matrix, std)
#     189         return nld, gsf
#     190
#
# ~/ompy/ompy/extractor.py in decompose(self, matrix, std, x0, product)
#     244         dEg = matrix.Eg[1] - matrix.Eg[0]
#     245         assert dEx == dEg, \
# --> 246             "Ex and Eg must have the same bin width. Currently they have"\
#     247             f"dEx: {dEx:.1f} and dEg: {dEg:.1f}. You have to rebin.\n"\
#     248             "The `ensemble` class has a `rebin` method."
#
# AssertionError: Ex and Eg must have the same bin width. Currently they havedEx: 235.7 and dEg: 235.7. You have to rebin.
# The `ensemble` class has a `rebin` method.

# %%
# let's remove the nan-valued elements (unconstrained elements) for the further analysis
for nld in extractor.nld:
    nld.cut_nan()

for gsf in extractor.gsf:
    gsf.cut_nan()

# %% [markdown]
# Normalization parameters and explanation:
#
# D0: 4.6 +/- 0.7 Average s-wave resonance spacing D0 [eV] Taken from https://www-nds.iaea.org/RIPL-3/, https://www-nds.iaea.org/cgi-bin/ripl_den_ldp.pl?Z=92&A=233
#
# Sn: Neutron separation energy [MeV] Taken from https://www-nds.iaea.org/RIPL-3/, https://www-nds.iaea.org/cgi-bin/ripl_levels.pl?Z=92&A=233
#
# Spincut pars. Parameters necessary for the spin cut model:
#     NLDa: Level density parameter. Taken from https://journals.aps.org/prc/abstract/10.1103/PhysRevC.80.054310 (Egidy, Bucurescu 2009)
#
#     Eshift: Total backshift parameter. Taken from https://journals.aps.org/prc/abstract/10.1103/PhysRevC.80.054310 (Egidy, Bucurescu 2009)
#
#     sigma2_disc: spin cutoff parameter discrepancy?
#
# Jtarget: 5/2+ “Target” (A-1 nucleus) ground state spin. From https://www-nds.iaea.org/cgi-bin/ripl_levels.pl?Z=92&A=233
#
# nldnorm:
#     limit_low:
#
#     limit_high:
#
# gsfnorm:
#     Gg: Total average radiative width [meV]

# %%
#Normalization parameters

regenerator = True

norm_pars = om.NormalizationParameters(name='233U')
norm_pars.D0 = [4.6, 0.7]  # eV #SJEKK
norm_pars.Sn = [5.761930, 0]# MeV #SJEKK
norm_pars.spincutModel = 'Disc_and_EB05'  # see eg. Guttormsen et al., 2017, PRC 96, 024313
#SJEKK ALLE DISSE
norm_pars.spincutPars = {"mass":233, "NLDa":23.23, "Eshift":-0.33,
                         "Sn": norm_pars.Sn[0], "sigma2_disc":[1.5, 3.6]}
norm_pars.Jtarget = 5/2 # A-1 nucleus

# %%
# NLD normalizer parameters

normlog = om.introspection.get_logger('normalizer_nld', 'INFO')
nldnorm = om.NormalizerNLD(nld=extractor.nld[0], discrete='discrete_levels_U233.txt', regenerate=regenerator)
nldnorm.limit_low = [0.2, 0.6]
nldnorm.limit_high=[1.6, 2.6]
nldnorm.norm_pars = norm_pars

# %%
# gSF normalizer parameters

normlog = om.introspection.get_logger('normalizer_gsf', 'INFO')
gsfnorm = om.NormalizerGSF(normalizer_nld=nldnorm, gsf=extractor.gsf[0], regenerate=regenerator)

# to be used for gsf normalization
#SJEKK
norm_pars.Gg = [30.675, 7.4242]  #meV  Found using a mean value of the Gg values from higher and lower isotopes (RIPL3)

gsfnorm.norm_pars = norm_pars
gsfnorm.model_high.Efit = [3.5, 4.5]

# %%
nldnorm.normalize(limit_low = nldnorm.limit_low, limit_high=nldnorm.limit_high, norm_pars=norm_pars)
# Out:
# 2020-09-28 10:07:48,673 - ompy.normalizer_nld - INFO -
#
# ---------
# Normalizing nld #0
# 2020-09-28 10:07:49,767 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬───────────────────┬─────────────────────┬─────────────────────┐
# │ A                  │ α [MeV⁻¹]         │ T [MeV]             │ Eshift [MeV]        │
# ╞════════════════════╪═══════════════════╪═════════════════════╪═════════════════════╡
# │ 10.819964637514746 │ 1.078246301048827 │ 0.44224831462491976 │ -0.7177258451322788 │
# └────────────────────┴───────────────────┴─────────────────────┴─────────────────────┘
# 2020-09-28 10:07:49,768 - ompy.normalizer_nld - INFO - Starting multinest
#   analysing data from multinest/nld_norm_0_.txt
# 2020-09-28 10:08:06,828 - ompy.normalizer_nld - INFO - Multinest results:
# ┌────────────┬─────────────┬───────────────┬──────────────┐
# │ A          │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │
# ╞════════════╪═════════════╪═══════════════╪══════════════╡
# │ 12.8 ± 3.4 │ 0.91 ± 0.32 │ 0.432 ± 0.034 │ -0.54 ± 0.53 │
# └────────────┴─────────────┴───────────────┴──────────────┘
# 2020-09-28 10:08:06,829 - ompy.normalizer_nld - INFO - Saving to saved_run/normalizers/NormalizerNLD.pkl

# %%
gsfnorm.normalize()
# Out:
# 2020-09-28 10:08:08,189 - ompy.normalizer_gsf - INFO - Normalizing #0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-215-47b10a716890> in <module>
# ----> 1 gsfnorm.normalize()
#
# ~/ompy/ompy/normalizer_gsf.py in normalize(self, gsf, normalizer_nld, alpha, nld, nld_model, norm_pars, num)
#     201
#     202         # experimental Gg and calc. both in meV
# --> 203         B_norm = self.norm_pars.Gg[0] / self.Gg_before_norm()
#     204         # propagate uncertainty of D0
#     205         B_norm_unc = B_norm * self.norm_pars.D0[1] / self.norm_pars.D0[0]
#
# ~/ompy/ompy/normalizer_gsf.py in Gg_before_norm(self)
#     259         self.LOG.debug("Method to compute Gg: %s", self.method_Gg)
#     260         if self.method_Gg == "standard":
# --> 261             return self.Gg_standard()
#     262         else:
#     263             # placeholder if normalizations with
#
# ~/ompy/ompy/normalizer_gsf.py in Gg_standard(self)
#     338             return integral
#     339
# --> 340         integral = integrate()
#     341
#     342         # factor of 2 because of equi-parity `spinsum` instead of `spinsum(π)`,
#
# ~/ompy/ompy/normalizer_gsf.py in integrate()
#     334             Ex = self.norm_pars.Sn[0] - Eg
#     335             integral = (np.power(Eg, 3) * wgsf(Eg) * wnld(Ex)
# --> 336                         * self.SpinSum(Ex, self.norm_pars.Jtarget))
#     337             integral = np.sum(integral) * stepsize
#     338             return integral
#
# ~/ompy/ompy/normalizer_gsf.py in wnld(E)
#     325
#     326         def wnld(E) -> ndarray:
# --> 327             return fnld(E, self.nld, self.nld_model)
#     328
#     329         def wgsf(E) -> ndarray:
#
# ~/ompy/ompy/normalizer_gsf.py in fnld(E, nld, nld_model)
#     592
#     593     conds = [E <= nld.E[-1], E > nld.E[-1]]
# --> 594     return np.piecewise(E, conds, [fexp, nld_model(E[conds[-1]])])
#     595
#     596
#
# <__array_function__ internals> in piecewise(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in piecewise(x, condlist, funclist, *args, **kw)
#     612             vals = x[condlist[k]]
#     613             if vals.size > 0:
# --> 614                 y[condlist[k]] = item(vals, *args, **kw)
#     615
#     616     return y
#
# ~/ompy/ompy/library.py in <lambda>(zz)
#     296     logy = np.log(yy)
#     297     lin_interp = interp1d(xx, logy, kind='linear', **kwargs)
# --> 298     log_interp = lambda zz: np.exp(lin_interp(zz))  # noqa
#     299     return log_interp
#     300
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/interpolate/polyint.py in __call__(self, x)
#      77         """
#      78         x, x_shape = self._prepare_x(x)
# ---> 79         y = self._evaluate(x)
#      80         return self._finish_y(y, x_shape)
#      81
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/interpolate/interpolate.py in _evaluate(self, x_new)
#     661         y_new = self._call(self, x_new)
#     662         if not self._extrapolate:
# --> 663             below_bounds, above_bounds = self._check_bounds(x_new)
#     664             if len(y_new) > 0:
#     665                 # Note fill_value must be broadcast up to the proper size
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/interpolate/interpolate.py in _check_bounds(self, x_new)
#     690         # !! Could provide more information about which values are out of bounds
#     691         if self.bounds_error and below_bounds.any():
# --> 692             raise ValueError("A value in x_new is below the interpolation "
#     693                              "range.")
#     694         if self.bounds_error and above_bounds.any():
#
# ValueError: A value in x_new is below the interpolation range.

# %% [markdown]
# Simultaneous normalization of the whole ensemble

# %%
normlog = om.introspection.get_logger('normalizer_simultan', 'INFO')
simnorm = om.NormalizerSimultan(normalizer_nld=nldnorm, normalizer_gsf=gsfnorm, regenerate=regenerator)
simnorm.gsf = extractor.gsf[0]
simnorm.nld = extractor.nld[0]

# running faster than the default 400 given less precise answers
# For propper calc. you may rather increase this to > 400.
simnorm.multinest_kwargs["n_live_points"] = 10
simnorm.normalize()
# Out:
# 2020-09-21 14:46:36,575 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬───────────────────┬─────────────────────┬─────────────────────┐
# │ A                  │ α [MeV⁻¹]         │ T [MeV]             │ Eshift [MeV]        │
# ╞════════════════════╪═══════════════════╪═════════════════════╪═════════════════════╡
# │ 6.0221312720236435 │ 1.271600013832233 │ 0.46032687876083944 │ -1.0029306431086773 │
# └────────────────────┴───────────────────┴─────────────────────┴─────────────────────┘
# 2020-09-21 14:46:36,633 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-21 14:46:36,639 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌────────────────────┬───────────────────┬─────────────────────┬─────────────────────┬──────────────────┐
# │ A                  │ α [MeV⁻¹]         │ T [MeV]             │ Eshift [MeV]        │ B                │
# ╞════════════════════╪═══════════════════╪═════════════════════╪═════════════════════╪══════════════════╡
# │ 6.0221312720236435 │ 1.271600013832233 │ 0.46032687876083944 │ -1.0029306431086773 │ 9.10604396462241 │
# └────────────────────┴───────────────────┴─────────────────────┴─────────────────────┴──────────────────┘
# 2020-09-21 14:46:36,639 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_0_.txt
# 2020-09-21 14:46:40,702 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 7.7 ± 1.1 │ 0.69 ± 0.17 │ 0.403 ± 0.021 │ -0.08 ± 0.29 │ 71 ± 56 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────┘
# 2020-09-21 14:46:40,707 - ompy.normalizer_simultan - INFO - Saving to normalizers/NormalizerSimultan.pkl

# %%
fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth))
simnorm.plot(ax=ax, add_figlegend=False);
fig.legend(loc=9, ncol=4, frameon=True, fontsize=label_fontsize)
ax[0].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax[0].set_ylabel('Nuclear Level Density (NLD)',fontsize=label_fontsize)
ax[1].set_ylabel('$\gamma SF$',fontsize=label_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('normalized_nld_gsf', dpi=save_dpi)

# %%
normlog = om.introspection.get_logger('normalizer_emsemble_simultan', 'INFO')
ensemblenorm_sim = om.EnsembleNormalizer(extractor=extractor, normalizer_simultan=simnorm, regenerate=regenerator)

ensemblenorm_sim.normalize()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 2020-09-21 14:46:43,911 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╡
# │ 4.108237213051706 │ 1.3129375830137433 │ 0.4556187242156153 │ -0.9292517281658921 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┘
# 2020-09-21 14:46:43,989 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-21 14:46:43,997 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┬────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │ B                  │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╪════════════════════╡
# │ 4.108237213051706 │ 1.3129375830137433 │ 0.4556187242156153 │ -0.9292517281658921 │ 13.826384018959574 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┴────────────────────┘
# 2020-09-21 14:46:44,000 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-21 14:46:44,381 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬───────────────────┬─────────────────────┬────────────────────┐
# │ A                  │ α [MeV⁻¹]         │ T [MeV]             │ Eshift [MeV]       │
# ╞════════════════════╪═══════════════════╪═════════════════════╪════════════════════╡
# │ 6.0221749357548955 │ 1.271595584775431 │ 0.46032706388529343 │ -1.002930408640269 │
# └────────────────────┴───────────────────┴─────────────────────┴────────────────────┘
# 2020-09-21 14:46:44,480 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-21 14:46:44,489 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌────────────────────┬───────────────────┬─────────────────────┬────────────────────┬───────────────────┐
# │ A                  │ α [MeV⁻¹]         │ T [MeV]             │ Eshift [MeV]       │ B                 │
# ╞════════════════════╪═══════════════════╪═════════════════════╪════════════════════╪═══════════════════╡
# │ 6.0221749357548955 │ 1.271595584775431 │ 0.46032706388529343 │ -1.002930408640269 │ 9.106088444050258 │
# └────────────────────┴───────────────────┴─────────────────────┴────────────────────┴───────────────────┘
# 2020-09-21 14:46:44,493 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-21 14:46:45,618 - ompy.normalizer_nld - INFO - DE results:
# ┌──────────────────┬────────────────────┬────────────────────┬─────────────────────┐
# │ A                │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │
# ╞══════════════════╪════════════════════╪════════════════════╪═════════════════════╡
# │ 4.04099812338599 │ 1.4996564181630796 │ 0.4559426790950101 │ -0.9343392451919492 │
# └──────────────────┴────────────────────┴────────────────────┴─────────────────────┘
# 2020-09-21 14:46:45,720 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-21 14:46:45,729 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌──────────────────┬────────────────────┬────────────────────┬─────────────────────┬───────────────────┐
# │ A                │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │ B                 │
# ╞══════════════════╪════════════════════╪════════════════════╪═════════════════════╪═══════════════════╡
# │ 4.04099812338599 │ 1.4996564181630796 │ 0.4559426790950101 │ -0.9343392451919492 │ 16.93284033412857 │
# └──────────────────┴────────────────────┴────────────────────┴─────────────────────┴───────────────────┘
# 2020-09-21 14:46:45,736 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_2_.txt2020-09-21 14:46:48,644 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 5.9 ± 1.3 │ 0.62 ± 0.14 │ 0.396 ± 0.015 │ 0.15 ± 0.22  │ 84 ± 33 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────┘
#
#   analysing data from multinest/sim_norm_0_.txt
# 2020-09-21 14:46:50,701 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 7.7 ± 1.1 │ 0.69 ± 0.17 │ 0.403 ± 0.021 │ -0.08 ± 0.29 │ 71 ± 56 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────┘
# 2020-09-21 14:46:51,806 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 4.536333428205214 │ 1.3083776588482374 │ 0.45153552859672097 │ -0.8653250494780322 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-09-21 14:46:51,903 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-21 14:46:51,910 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┬────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                  │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╪════════════════════╡
# │ 4.536333428205214 │ 1.3083776588482374 │ 0.45153552859672097 │ -0.8653250494780322 │ 15.693252757258076 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┴────────────────────┘
# 2020-09-21 14:46:51,917 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-21 14:46:52,044 - ompy.normalizer_nld - INFO - DE results:
# ┌─────────────────┬───────────────────┬─────────────────────┬─────────────────────┐
# │ A               │ α [MeV⁻¹]         │ T [MeV]             │ Eshift [MeV]        │
# ╞═════════════════╪═══════════════════╪═════════════════════╪═════════════════════╡
# │ 4.1937828832533 │ 1.392674142747653 │ 0.46010486492452823 │ -0.9996947822223297 │
# └─────────────────┴───────────────────┴─────────────────────┴─────────────────────┘
# 2020-09-21 14:46:52,133 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-21 14:46:52,140 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌─────────────────┬───────────────────┬─────────────────────┬─────────────────────┬────────────────────┐
# │ A               │ α [MeV⁻¹]         │ T [MeV]             │ Eshift [MeV]        │ B                  │
# ╞═════════════════╪═══════════════════╪═════════════════════╪═════════════════════╪════════════════════╡
# │ 4.1937828832533 │ 1.392674142747653 │ 0.46010486492452823 │ -0.9996947822223297 │ 15.689201160474264 │
# └─────────────────┴───────────────────┴─────────────────────┴─────────────────────┴────────────────────┘
# 2020-09-21 14:46:52,145 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_1_.txt
# 2020-09-21 14:46:54,670 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬───────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]     │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═══════════════╪═══════════════╪══════════════╪═════════╡
# │ 5.2 ± 1.0 │ 0.891 ± 0.065 │ 0.395 ± 0.011 │ 0.03 ± 0.12  │ 80 ± 15 │
# └───────────┴───────────────┴───────────────┴──────────────┴─────────┘
# 2020-09-21 14:46:56,664 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╡
# │ 4.653765886720724 │ 1.4773469376889368 │ 0.4643958062627739 │ -1.0669298215515415 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┘
#   analysing data from multinest/sim_norm_4_.txt
# 2020-09-21 14:46:56,698 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬──────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪══════════╡
# │ 7.4 ± 1.1 │ 0.50 ± 0.14 │ 0.379 ± 0.010 │ 0.32 ± 0.15  │ 188 ± 97 │
# └───────────┴─────────────┴───────────────┴──────────────┴──────────┘
# 2020-09-21 14:46:56,765 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-21 14:46:56,773 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┬────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │ B                  │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╪════════════════════╡
# │ 4.653765886720724 │ 1.4773469376889368 │ 0.4643958062627739 │ -1.0669298215515415 │ 10.170862908979203 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┴────────────────────┘
# 2020-09-21 14:46:56,775 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-21 14:46:58,179 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 4.675130973944713 │ 1.3853686185730725 │ 0.45436762222790344 │ -0.9098440649868106 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-09-21 14:46:58,266 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-21 14:46:58,273 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╪═══════════════════╡
# │ 4.675130973944713 │ 1.3853686185730725 │ 0.45436762222790344 │ -0.9098440649868106 │ 18.20915596629316 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┴───────────────────┘
# 2020-09-21 14:46:58,278 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_3_.txt
# 2020-09-21 14:47:00,053 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────────┬─────────────┬───────────────┬──────────────┬──────────┐
# │ A           │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞═════════════╪═════════════╪═══════════════╪══════════════╪══════════╡
# │ 7.05 ± 0.97 │ 0.59 ± 0.17 │ 0.389 ± 0.017 │ 0.15 ± 0.26  │ 102 ± 64 │
# └─────────────┴─────────────┴───────────────┴──────────────┴──────────┘
# 2020-09-21 14:47:01,420 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬───────────────────┬────────────────────┬─────────────────────┐
# │ A                  │ α [MeV⁻¹]         │ T [MeV]            │ Eshift [MeV]        │
# ╞════════════════════╪═══════════════════╪════════════════════╪═════════════════════╡
# │ 3.5543759064303377 │ 1.540300264905087 │ 0.4576559628553112 │ -0.9611049086920811 │
# └────────────────────┴───────────────────┴────────────────────┴─────────────────────┘
# 2020-09-21 14:47:01,507 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-21 14:47:01,514 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌────────────────────┬───────────────────┬────────────────────┬─────────────────────┬────────────────────┐
# │ A                  │ α [MeV⁻¹]         │ T [MeV]            │ Eshift [MeV]        │ B                  │
# ╞════════════════════╪═══════════════════╪════════════════════╪═════════════════════╪════════════════════╡
# │ 3.5543759064303377 │ 1.540300264905087 │ 0.4576559628553112 │ -0.9611049086920811 │ 19.433207911614705 │
# └────────────────────┴───────────────────┴────────────────────┴─────────────────────┴────────────────────┘
# 2020-09-21 14:47:01,520 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_5_.txt
# 2020-09-21 14:47:03,117 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 6.5 ± 1.8 │ 0.83 ± 0.15 │ 0.397 ± 0.012 │ -0.02 ± 0.16 │ 55 ± 25 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────┘
# 2020-09-21 14:47:05,708 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬────────────────────┬─────────────────────┬────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]       │
# ╞════════════════════╪════════════════════╪═════════════════════╪════════════════════╡
# │ 6.1977660508153765 │ 1.2987661566055928 │ 0.45972039370486817 │ -0.993296519797614 │
# └────────────────────┴────────────────────┴─────────────────────┴────────────────────┘
# 2020-09-21 14:47:05,806 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-21 14:47:05,816 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌────────────────────┬────────────────────┬─────────────────────┬────────────────────┬────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]       │ B                  │
# ╞════════════════════╪════════════════════╪═════════════════════╪════════════════════╪════════════════════╡
# │ 6.1977660508153765 │ 1.2987661566055928 │ 0.45972039370486817 │ -0.993296519797614 │ 16.564994946225703 │
# └────────────────────┴────────────────────┴─────────────────────┴────────────────────┴────────────────────┘
# 2020-09-21 14:47:05,822 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_7_.txt
# 2020-09-21 14:47:07,663 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬─────────────────┬──────────────┬──────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]         │ Eshift [MeV] │ B        │
# ╞═══════════╪═════════════╪═════════════════╪══════════════╪══════════╡
# │ 5.9 ± 1.2 │ 0.84 ± 0.11 │ 0.4038 ± 0.0076 │ -0.03 ± 0.12 │ 108 ± 43 │
# └───────────┴─────────────┴─────────────────┴──────────────┴──────────┘
#   analysing data from multinest/sim_norm_6_.txt
# 2020-09-21 14:47:09,492 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 6.5 ± 1.6 │ 0.95 ± 0.25 │ 0.421 ± 0.017 │ -0.35 ± 0.27 │ 55 ± 55 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────┘
# 2020-09-21 14:47:09,903 - ompy.normalizer_nld - INFO - DE results:
# ┌──────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 7.21023726949564 │ 1.2112695989569728 │ 0.45874051678533984 │ -0.9784450131043957 │
# └──────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-09-21 14:47:09,980 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-21 14:47:09,987 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌──────────────────┬────────────────────┬─────────────────────┬─────────────────────┬────────────────────┐
# │ A                │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                  │
# ╞══════════════════╪════════════════════╪═════════════════════╪═════════════════════╪════════════════════╡
# │ 7.21023726949564 │ 1.2112695989569728 │ 0.45874051678533984 │ -0.9784450131043957 │ 10.515736816070651 │
# └──────────────────┴────────────────────┴─────────────────────┴─────────────────────┴────────────────────┘
# 2020-09-21 14:47:09,989 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_8_.txt
# 2020-09-21 14:47:10,407 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 8.2 ± 1.4 │ 0.77 ± 0.20 │ 0.411 ± 0.017 │ -0.25 ± 0.25 │ 79 ± 52 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────┘
#   analysing data from multinest/sim_norm_9_.txt
# 2020-09-21 14:47:14,630 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 9.0 ± 1.8 │ 0.83 ± 0.18 │ 0.424 ± 0.020 │ -0.47 ± 0.29 │ 39 ± 32 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────┘

# %%
fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth+3))
ensemblenorm_sim.plot(ax=ax, n_plot=5, add_figlegend=False)#, random_state=np.random.default_rng(65546645));
fig.legend(loc=9, ncol=4, frameon=True, fontsize=label_fontsize)
ax[0].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax[0].set_ylabel('Level Density $\\rho(E_x)$ $[MeV^{-1}]$',fontsize=label_fontsize)
ax[1].set_ylabel('$\gamma-SF$ $f(E_\gamma)\sim [MeV^{-3}]$',fontsize=label_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
