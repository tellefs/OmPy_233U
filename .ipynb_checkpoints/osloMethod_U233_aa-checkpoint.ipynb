# %% [markdown]
# Import useful programs

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import ompy as om
import logging

import scipy as sp
#%matplotlib widget
from ipywidgets import widgets #interact, interactive, fixed, interact_manual

from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
om.__full_version__;

# %%
# For reproducability we seed the random generator.
# Note that by default several other classes in ompy, such as all
# classes with multinest calculations have a default seed, too
np.random.seed(1382398)

# %%
# get smaller files for the online version
plt.rcParams["figure.dpi"] = 80

# %%
major_tick_length=12
minor_tick_length=5
tick_width=2
tick_labelsize=22
label_fontsize=22
title_fontsize=22
figwidth=10
figheigth=8
save_dpi = 100


def plot_3D(matrix, filename, xlabel='xlabel', ylabel='ylabel'):
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    matrix.plot(ax=ax);
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(axis='both', which='both', labelsize=tick_labelsize, width=tick_width)
    ax.tick_params(axis='both', which='major', length=major_tick_length)
    ax.tick_params(axis='both', which='minor', length=minor_tick_length)
    ax.set_xlabel(xlabel,fontsize=label_fontsize)
    ax.set_ylabel(ylabel,fontsize=label_fontsize)
    fig.axes[1].tick_params(labelsize=tick_labelsize)
    ax.grid(color='k', linestyle='--', linewidth=.5)
    fig.savefig(filename, dpi=save_dpi)
    
def plot_2D(matrix, filename, projection_axis, xlabel='xlabel', ylabel='ylabel', yscale='log'):
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    matrix.plot_projection(projection_axis, kind="step", ax=ax);
    plt.yscale(yscale)
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(axis='both', which='both', labelsize=tick_labelsize, width=tick_width)
    ax.tick_params(axis='both', which='major', length=major_tick_length)
    ax.tick_params(axis='both', which='minor', length=minor_tick_length)
    ax.set_xlabel(xlabel,fontsize=label_fontsize)
    ax.set_ylabel(ylabel,fontsize=label_fontsize)
    ax.grid(color='k', linestyle='--', linewidth=.5)
    fig.savefig(filename, dpi=save_dpi)

# %%
def plot_matrix(matrix, fig_name, title, scale='log', x_label='$\gamma$-ray energy $E_\gamma$', ylabel='Excitation energy $E_x$'):
    fig, ax = plt.subplots(figsize=(10, 8))
    matrix.plot(ax=ax, scale=scale);
    ax.tick_params(axis='both', labelsize=18)
    ax.set_xlabel('$\gamma$-ray energy $E_\gamma$',fontsize=18)
    ax.set_ylabel('Excitation energy $E_x$',fontsize=18)
    ax.set_title(None)
    fig.suptitle(title, fontsize=20)
    fig.axes[1].tick_params(labelsize=18)
    fig.savefig(fig_name)

# %%
# Import raw matrix into instance of om.Matrix()
#raw = om.Matrix(path="alfna_matrix/alfna_U233")
raw = om.Matrix(path="alfna_matrix/alfna_right_bg_timecuts")
raw_fiss = om.Matrix(path="alfna_matrix/alfna_fiss_right_bg_timecuts")

#Rebin matrices
raw.rebin(0,factor=12)
raw.rebin(1,factor=12)
raw_fiss.rebin(0,factor=12)
raw_fiss.rebin(1,factor=12)

# %%
#plot raw matrix
raw_plot_big = raw.copy()
raw_plot_big.cut('Ex', 0, 8000)
raw_plot_big.cut('Eg', 0, 6000)

Ex = raw_plot_big.Ex
Eg = raw_plot_big.Eg

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
raw_plot_big.plot(ax=ax, vmin=1e-1, vmax=1e2);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot(Eg, Eg, "r--", label="E_x = E_g", linewidth=3.0);
fig.axes[1].tick_params(labelsize=tick_labelsize)

#Plot new diagonal to be used for calibration

#Linefit to calibrate Ex

#finding calibration points alog the diagonal
p0 = [0,0]
p1 = [500, 700]
p2 = [1000, 1200]
p3 = [1500, 1800]
p4 = [2000, 2300]
p5 = [2350, 2600]

#linefit
y_linefit = np.asarray([p0[1], p1[1], p2[1], p3[1], p4[1], p5[1]])
x_linefit = np.asarray([p0[0], p1[0], p2[0], p3[0], p4[0], p5[0]])
z = np.polyfit(x_linefit, y_linefit, 1)
poly = np.poly1d(z)
new_diag = Eg*poly[1] + poly[0]
ax.plot(Eg, new_diag, 'r--', linewidth=3.0);

#finding calibration points alog the diagonal
ax.plot(p0[0], p0[1], 'ko', markersize=7.0);
ax.plot(p1[0], p1[1], 'ko', markersize=7.0);
ax.plot(p2[0], p2[1], 'ko', markersize=7.0);
ax.plot(p3[0], p3[1], 'ko', markersize=7.0);
ax.plot(p4[0], p4[1], 'ko', markersize=7.0);
ax.plot(p5[0], p5[1], 'ko', markersize=7.0);



fig.savefig('plots/raw_uncalibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 1800], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 1800], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=label_fontsize, loc='upper left');
fig.savefig('plots/Ex_py_uncalibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw_fiss.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 200], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 200], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=label_fontsize, loc='upper left');
fig.savefig('plots/Ex_py_fiss_uncalibrated', dpi=save_dpi)

# %%
#Calibrate Ex to new diagonal which is decided here
new_diag = raw.Ex*poly[1] + poly[0]
raw.Ex = 2*raw.Ex - new_diag
raw_fiss.Ex = 2*raw_fiss.Ex - new_diag

# %%
#plot raw matrix after calibration

raw_plot_big = raw.copy()
raw_plot_big.cut('Ex', 0, 8000)
raw_plot_big.cut('Eg', 0, 6000)


fig, ax = plt.subplots(figsize=(figwidth, figheigth))
raw_plot_big.plot(ax=ax, vmin=1e-1, vmax=1e2);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
x = np.linspace(0, 6000, len(raw.Ex))
ax.plot(x, x, "r--", label="E_x = E_g", linewidth=3.0);
#ax.plot(x, np.ones(len(raw.Ex))*5550, 'r--'); #fission barrier
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/raw_calibrated', dpi=save_dpi)

#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 1300], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 1300], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=16, loc='upper right');
fig.savefig('plots/Ex_py_calibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw_fiss.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 150], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 150], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=16, loc='upper right');
fig.savefig('plots/Ex_py_fiss_calibrated', dpi=save_dpi)

# %%
#Rebin raw matrix

def rebin_cut_raw(raw, kev_per_bin_wish, cut, keep=False):
    """
    Cuts raw matrix Eg and Ex at approximately cut and rebins Eg and Ex with new kev_per_bin_wish
    Cuts away diagonal too
    """
    
    raw_rebin = raw.copy()
    cut = kev_per_bin_wish*round(cut/kev_per_bin_wish)
    raw_rebin.cut('Ex', 0, cut)
    raw_rebin.cut('Eg', 0, cut)
 
    new_mids = np.linspace(kev_per_bin_wish/2, cut-(kev_per_bin_wish/2), int(cut/kev_per_bin_wish))    
    raw_rebin.rebin('Ex', mids=new_mids) #rebinning the Eg energy axis
    raw_rebin.rebin('Eg', mids=new_mids) #rebinning the Ex energy axis
    
    raw_rebin.cut_diagonal(E1=(kev_per_bin_wish, 0), E2 = (cut*2 + kev_per_bin_wish, cut*2))
    #raw_rebin.cut_diagonal(E1=(0, 0), E2 = (cut*2, cut*2))
    
    dEx = raw_rebin.Ex[1] - raw_rebin.Ex[0]
    print('New KeV per bin: %.3f'%dEx)

    #plot matrix
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    raw_rebin.plot(ax=ax, vmin=1e-1, vmax=1e3);
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(axis='both', which='both', labelsize=tick_labelsize, width=tick_width)
    ax.tick_params(axis='both', which='major', length=major_tick_length)
    ax.tick_params(axis='both', which='minor', length=minor_tick_length)
    ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
    ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
    fig.axes[1].tick_params(labelsize=tick_labelsize)
    x = np.linspace(0, cut-kev_per_bin_wish, len(raw.Ex))
    ax.plot(x, x, "r--", label="E_x = E_g", linewidth=3.0);
    ax.grid(color='k', linestyle='--', linewidth=.5)
    fig.savefig('plots/rebinned_matrix', dpi=save_dpi)
    if keep==True:
        return raw_rebin
        #raw=raw_rebin
        #raw.rebin('Ex', mids=new_mids)
        #raw.rebin('Eg', mids=new_mids)
    if keep==False:
        return raw
        
keep = True
raw = rebin_cut_raw(raw, kev_per_bin_wish=250, cut=6000, keep=keep)
# Out:
# New KeV per bin: 250.000

# %% [markdown]
# From the GettingStarted OmPy manual: "Eventhough this experiment was performed with CACTUS, we will now give an example as if the data was taken with OSCAR. This is beacause it is slightly easier to handle. For CACTUS, the response functions do not include the detector threshold; this has do be taken into account separately."
#
# So, I need to include the detector threshold for CACTUS

# %%
### GETTING RESPONSE MATRIX


logger = om.introspection.get_logger('response', 'INFO')
# Then do the same using OMpy functionality:
# You may need to adpot this to whereever you response matrixes are stored
folderpath = "../OCL_response_functions/nai2012_for_opt13"

# Energy calibration of resulting response matrix:
Eg = raw.Eg

# Experimental relative FWHM at 1.33 MeV of resulting array
fwhm_abs = 90.44 # (90/1330 = 6.8%) #CACTUS

response = om.Response(folderpath)
R_ompy_view, R_tab_view = response.interpolate(Eg, fwhm_abs=fwhm_abs, return_table=True)
# Magne recommends 1/10 of the actual resolution for unfolding purposes (see article)
R_ompy_unf, R_tab_unf = response.interpolate(Eg, fwhm_abs=fwhm_abs/10, return_table=True)

R_ompy_view.save("R_ompy_view.m")
R_ompy_unf.save("R_ompy_unf.m")
R_tab_view.to_pickle("R_tab_view.pkl")
R_tab_unf.to_pickle("R_tab_unf.pkl")

# adding response function for CACTUS
fthreshold = sp.interpolate.interp1d([30., 80., 122., 183., 244., 294., 344., 562., 779., 1000.],
                      [0.0, 0.0, 0.0, 0.06, 0.44, 0.60, 0.87, 0.99, 1.00, 1.00],
                      fill_value="extrapolate") #from mama-software ('folding.f')

def apply_detector_threshold(response, table, fthreshold):
    thres = fthreshold(response.Eg)
    response.values = response.values * thres
    # renormalize
    response.values = om.div0(response.values, response.values.sum(axis=1)[:, np.newaxis])
    table["eff_tot"] *= thres

apply_detector_threshold(R_ompy_unf, R_tab_unf, fthreshold)
apply_detector_threshold(R_ompy_view, R_tab_view, fthreshold)


fig, ax = plt.subplots(figsize=(figwidth, figheigth))
R_ompy_view.plot(ax=ax, scale="log", vmin=1e-5, vmax=1e0);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Response Matrix', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/response_matrix', dpi=save_dpi)
# Out:
# 2020-09-28 14:28:17,633 - ompy.response - INFO - Note: Spectra outside of 360.0 and 15000.0 are extrapolation only.
# 2020-09-28 14:28:17,759 - ompy.response - INFO - Note: Spectra outside of 360.0 and 15000.0 are extrapolation only.

# %%
### UNFOLDING

# You can decide to log information and set the logging level (info/debug)
logger = om.introspection.get_logger('unfolder', 'INFO')

# We need to remove negative counts (unphysical) in the raw matrix before unfolding:
raw_positive = raw.copy()
raw_positive.fill_and_remove_negative(window_size=20)
plot_matrix(raw_positive, 'plots/raw_positive_matrix', title='Raw positive matrix')

# With compton subtraction and all tweaks
unfolder = om.Unfolder(response=R_ompy_unf)
unfolder.use_compton_subtraction = True # default
unfolder.response_tab = R_tab_unf
# Magne suggests some "tweaks" for a better unfolding performance. Default is 1 for all.
unfolder.FWHM_tweak_multiplier = {"fe": 1., "se": 1.1,
                                     "de": 1.3, "511": 0.9} #SJEKK DETTE
unfolded = unfolder(raw_positive)

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
unfolded.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e3);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Unfolded', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/unfolded_matrix', dpi=save_dpi)

# %%
### Generate the first generation matrix

firstgen = om.FirstGeneration()
primary = firstgen(unfolded)

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
primary.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e3);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Primary', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/firstgen_matrix', dpi=save_dpi)

# %%
### Propagating statistical uncertainties

logger = om.introspection.get_logger('ensemble', 'INFO')

# Tell the `Ensemble` class which raw spectrum, what kind of unfolder and first
# generations method to use.
# Note: This will have the same setting as above. We could for example have
# set the first generations method to use a different "valley_collection", or a
# differnt type of "multiplicity_estimation"
ensemble = om.Ensemble(raw=raw_positive)
ensemble.unfolder = unfolder
ensemble.first_generation_method = firstgen
# Generates N perturbated members; here just 10 to speed it up
# the `regenerate` flag ensures, that we don't load from disk; which might result in expected results
# if we have changed something in the input `raw` matrix.
ensemble.generate(10, regenerate=True)
# Out:
# 2020-09-28 14:28:20,436 - ompy.ensemble - INFO - Start normalization with 3 cpus
# 2020-09-28 14:28:20,520 - ompy.ensemble - INFO - Generating/loading 0
# 2020-09-28 14:28:20,538 - ompy.ensemble - INFO - Generating/loading 1
# 2020-09-28 14:28:20,554 - ompy.ensemble - INFO - Generating/loading 2
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 2020-09-28 14:28:20,634 - ompy.ensemble - INFO - Generating/loading 3
# 2020-09-28 14:28:20,669 - ompy.ensemble - INFO - Generating/loading 4
# 2020-09-28 14:28:20,706 - ompy.ensemble - INFO - Generating/loading 5
# 2020-09-28 14:28:20,766 - ompy.ensemble - INFO - Generating/loading 6
# 2020-09-28 14:28:20,792 - ompy.ensemble - INFO - Generating/loading 7
# 2020-09-28 14:28:20,833 - ompy.ensemble - INFO - Generating/loading 8
# 2020-09-28 14:28:20,873 - ompy.ensemble - INFO - Generating/loading 9

# %%
#old plotting of unfolded and ensemble
#i_unfolded = 9
#matrix = ensemble.get_unfolded(i_unfolded)
#matrix.plot(title=f"Unfolded matrix #{i_unfolded}")

# Following commands plots all std. deviations
#ensemble.plot();

# %% [markdown]
# Extract Nuclear level density and gamma strength function

# %%
extlog = om.introspection.get_logger('extractor', 'INFO')
trapezoid_cut = om.Action('matrix')
# Trapezoidal cuts
Ex_min = 2000
Ex_max = 5300
Eg_min = 1000
Eg_max = 6000

#plot primary matrix with trapezoidal cuts:
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
primary.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e3);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
# Trapez
x = [Eg_min, Ex_min, Ex_max, Eg_min]
y = [Ex_min, Ex_min, Ex_max, Ex_max]
textstr = '\n'.join((
    r'$E_{x, min}=%.0f$' % (Ex_min, ),
    r'$E_{x, max}=%.0f$' % (Ex_max, ),
    r'$E_{\gamma, min}=%.0f$' % (Eg_min, ),
    r'$E_{\gamma, max}=%.0f$' % (Eg_max, )))
# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
# place a text box in upper left in axes coords
ax.text(.70, 0.25, textstr, transform=ax.transAxes, fontsize=14, verticalalignment='top', bbox=props)

ax.add_patch(patches.Polygon(xy=list(zip(x,y)), fill=False, linewidth=3.0, color='r', linestyle='--'))
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/firstgen_trapezoid', dpi=save_dpi)


#Perform trapezoidal cut
trapezoid_cut.trapezoid(Ex_min=Ex_min, Ex_max=Ex_max, Eg_min=Eg_min, Eg_max = Eg_max, inplace=True)
extractor = om.Extractor()
extractor.trapezoid = trapezoid_cut


E_rebinned = ensemble.get_firstgen(0).Ex
ensemble.rebin(E_rebinned, member="firstgen")

extractor.extract_from(ensemble, regenerate=True)

extractor.plot(scale='log', plot_mean=False);
plt.savefig('unnormed_new_falsemean')

extractor.plot(scale='log', plot_mean=True);
plt.savefig('unnormed_new_truemean')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 2020-09-28 14:28:21,427 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-28 14:28:21,428 - ompy.extractor - INFO - Minimizing
# 2020-09-28 14:28:21,539 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-28 14:28:21,539 - ompy.extractor - INFO -          Current function value: 426.713597
# 2020-09-28 14:28:21,540 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-28 14:28:21,540 - ompy.extractor - INFO -          Function evaluations: 2206
# 2020-09-28 14:28:21,565 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-28 14:28:21,566 - ompy.extractor - INFO - Minimizing
# 2020-09-28 14:28:21,708 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-28 14:28:21,708 - ompy.extractor - INFO -          Current function value: 398.752169
# 2020-09-28 14:28:21,709 - ompy.extractor - INFO -          Iterations: 5
# 2020-09-28 14:28:21,710 - ompy.extractor - INFO -          Function evaluations: 2818
# 2020-09-28 14:28:21,749 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-28 14:28:21,750 - ompy.extractor - INFO - Minimizing
# 2020-09-28 14:28:21,890 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-28 14:28:21,890 - ompy.extractor - INFO -          Current function value: 439.957384
# 2020-09-28 14:28:21,891 - ompy.extractor - INFO -          Iterations: 5
# 2020-09-28 14:28:21,891 - ompy.extractor - INFO -          Function evaluations: 2755
# 2020-09-28 14:28:21,916 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-28 14:28:21,917 - ompy.extractor - INFO - Minimizing
# 2020-09-28 14:28:22,060 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-28 14:28:22,060 - ompy.extractor - INFO -          Current function value: 453.561380
# 2020-09-28 14:28:22,061 - ompy.extractor - INFO -          Iterations: 5
# 2020-09-28 14:28:22,062 - ompy.extractor - INFO -          Function evaluations: 2807
# 2020-09-28 14:28:22,086 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-28 14:28:22,087 - ompy.extractor - INFO - Minimizing
# 2020-09-28 14:28:22,203 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-28 14:28:22,203 - ompy.extractor - INFO -          Current function value: 403.594775
# 2020-09-28 14:28:22,204 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-28 14:28:22,205 - ompy.extractor - INFO -          Function evaluations: 2256
# 2020-09-28 14:28:22,229 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-28 14:28:22,230 - ompy.extractor - INFO - Minimizing
# 2020-09-28 14:28:22,346 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-28 14:28:22,346 - ompy.extractor - INFO -          Current function value: 463.623582
# 2020-09-28 14:28:22,347 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-28 14:28:22,348 - ompy.extractor - INFO -          Function evaluations: 2260
# 2020-09-28 14:28:22,371 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-28 14:28:22,372 - ompy.extractor - INFO - Minimizing
# 2020-09-28 14:28:22,515 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-28 14:28:22,516 - ompy.extractor - INFO -          Current function value: 502.352533
# 2020-09-28 14:28:22,516 - ompy.extractor - INFO -          Iterations: 5
# 2020-09-28 14:28:22,517 - ompy.extractor - INFO -          Function evaluations: 2782
# 2020-09-28 14:28:22,543 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-28 14:28:22,544 - ompy.extractor - INFO - Minimizing
# 2020-09-28 14:28:22,664 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-28 14:28:22,665 - ompy.extractor - INFO -          Current function value: 497.275113
# 2020-09-28 14:28:22,666 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-28 14:28:22,666 - ompy.extractor - INFO -          Function evaluations: 2198
# 2020-09-28 14:28:22,690 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-28 14:28:22,691 - ompy.extractor - INFO - Minimizing
# 2020-09-28 14:28:22,838 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-28 14:28:22,839 - ompy.extractor - INFO -          Current function value: 454.941839
# 2020-09-28 14:28:22,840 - ompy.extractor - INFO -          Iterations: 5
# 2020-09-28 14:28:22,841 - ompy.extractor - INFO -          Function evaluations: 2790
# 2020-09-28 14:28:22,866 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-28 14:28:22,867 - ompy.extractor - INFO - Minimizing
# 2020-09-28 14:28:23,018 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-28 14:28:23,019 - ompy.extractor - INFO -          Current function value: 389.901778
# 2020-09-28 14:28:23,019 - ompy.extractor - INFO -          Iterations: 5
# 2020-09-28 14:28:23,020 - ompy.extractor - INFO -          Function evaluations: 2842

# %%
# let's remove the nan-valued elements (unconstrained elements) for the further analysis
for nld in extractor.nld:
    nld.cut_nan()

for gsf in extractor.gsf:
    gsf.cut_nan()

# %% [markdown]
# Normalization parameters and explanation:
#
# D0: 4.6 +/- 0.7 Average s-wave resonance spacing D0 [eV] Taken from https://www-nds.iaea.org/RIPL-3/, https://www-nds.iaea.org/cgi-bin/ripl_den_ldp.pl?Z=92&A=233
#
# Sn: Neutron separation energy [MeV] Taken from https://www-nds.iaea.org/RIPL-3/, https://www-nds.iaea.org/cgi-bin/ripl_levels.pl?Z=92&A=233
#
# Spincut pars. Parameters necessary for the spin cut model:
#     NLDa: Level density parameter. Taken from https://journals.aps.org/prc/abstract/10.1103/PhysRevC.80.054310 (Egidy, Bucurescu 2009)
#
#     Eshift: Total backshift parameter. Taken from https://journals.aps.org/prc/abstract/10.1103/PhysRevC.80.054310 (Egidy, Bucurescu 2009)
#
#     sigma2_disc: spin cutoff parameter discrepancy?
#
# Jtarget: 5/2+ “Target” (A-1 nucleus) ground state spin. From https://www-nds.iaea.org/cgi-bin/ripl_levels.pl?Z=92&A=233
#
# nldnorm:
#     limit_low:
#
#     limit_high:
#
# gsfnorm:
#     Gg: Total average radiative width [meV]
#
#
# printout from ompy source-code
#         """ Get the square of the spin cut for a specified model
#
#         if model == "const":
#             pars_req = {"sigma"}
#             return call_model(self.gconst, pars, pars_req)
#         elif model == "EB05":
#             pars_req = {"mass", "NLDa", "Eshift"}
#             return call_model(self.gEB05, pars, pars_req)
#         elif model == "EB09_CT":
#             pars_req = {"mass"}
#             return call_model(self.gEB09_CT, pars, pars_req)
#         elif model == "EB09_emp":
#             pars_req = {"mass", "Pa_prime"}
#             return call_model(self.gEB09_emp, pars, pars_req)
#         elif model == "Disc_and_EB05":
#             pars_req = {"mass", "NLDa", "Eshift", "Sn", "sigma2_disc"}
#             return call_model(self.gDisc_and_EB05, pars, pars_req)
#
# The different spin-cutoff models to use. Which one?

# %%
#Normalization parameters

regenerator = True

norm_pars = om.NormalizationParameters(name='233U')
norm_pars.D0 = [4.6, 0.7]  # eV #SJEKK
norm_pars.Sn = [5.761930, 0]# MeV #SJEKK

#Which spin-cutoff model to use (uncomment to use):

norm_pars.spincutModel = 'Disc_and_EB05'  # see eg. Guttormsen et al., 2017, PRC 96, 024313
norm_pars.spincutPars = {"mass":233, "NLDa":23.23, "Eshift":-0.33, "Sn": norm_pars.Sn[0], "sigma2_disc":[1.5, 3.6]}

#norm_pars.spincutModel = 'EB09_CT'
#norm_pars.spincutPars = {"mass":233}

#norm_pars.spincutModel = 'EB05'
#norm_pars.spincutPars = {"mass":233, "NLDa":23.23, "Eshift":-0.33}


norm_pars.Jtarget = 5/2 # A-1 nucleus

# NLD normalizer parameters

normlog = om.introspection.get_logger('normalizer_nld', 'INFO')
nldnorm = om.NormalizerNLD(nld=extractor.nld[0], discrete='discrete_levels_U233.txt', regenerate=regenerator)
nldnorm.limit_low = [0.2, 0.6]
nldnorm.limit_high=[1.6, 2.6]
nldnorm.norm_pars = norm_pars

# gSF normalizer parameters

normlog = om.introspection.get_logger('normalizer_gsf', 'INFO')
gsfnorm = om.NormalizerGSF(normalizer_nld=nldnorm, gsf=extractor.gsf[0], regenerate=regenerator)

# to be used for gsf normalization
norm_pars.Gg = [30.675, 7.4242]  #meV  Found using a mean value of the Gg values from higher and lower isotopes (RIPL3)

gsfnorm.norm_pars = norm_pars
gsfnorm.model_high.Efit = [2.5, 3]

# %%
nldnorm.normalize(limit_low = nldnorm.limit_low, limit_high=nldnorm.limit_high, norm_pars=norm_pars)
# Out:
# 2020-09-28 14:28:27,108 - ompy.normalizer_nld - INFO -
#
# ---------
# Normalizing nld #0
# 2020-09-28 14:28:27,905 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 7.595098927082259 │ 0.8183843596955354 │ 0.42654980555528693 │ -0.4761233735795114 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-09-28 14:28:27,906 - ompy.normalizer_nld - INFO - Starting multinest
#   analysing data from multinest/nld_norm_0_.txt
# 2020-09-28 14:28:43,945 - ompy.normalizer_nld - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╡
# │ 9.3 ± 2.4 │ 0.55 ± 0.35 │ 0.411 ± 0.030 │ -0.21 ± 0.46 │
# └───────────┴─────────────┴───────────────┴──────────────┘
# 2020-09-28 14:28:43,946 - ompy.normalizer_nld - INFO - Saving to saved_run/normalizers/NormalizerNLD.pkl

# %%
gsfnorm.normalize()
# Out:
# 2020-09-28 14:28:43,988 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:28:43,993 - ompy.normalizer_gsf - INFO - Saving to saved_run/normalizers/NormalizerGSF.pkl

# %% [markdown]
# Simultaneous normalization of the whole ensemble

# %%
normlog = om.introspection.get_logger('normalizer_simultan', 'INFO')
simnorm = om.NormalizerSimultan(normalizer_nld=nldnorm, normalizer_gsf=gsfnorm, regenerate=regenerator)
simnorm.gsf = extractor.gsf[0]
simnorm.nld = extractor.nld[0]

# running faster than the default 400 given less precise answers
# For propper calc. you may rather increase this to > 400.
simnorm.multinest_kwargs["n_live_points"] = 10
simnorm.normalize()
# Out:
# 2020-09-28 14:28:44,831 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╡
# │ 7.595077289170001 │ 0.8183881584609067 │ 0.4265499611207884 │ -0.4761262823078706 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┘
# 2020-09-28 14:28:44,870 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:28:44,874 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╪═══════════════════╡
# │ 7.595077289170001 │ 0.8183881584609067 │ 0.4265499611207884 │ -0.4761262823078706 │ 48.35962805215871 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┴───────────────────┘
# 2020-09-28 14:28:44,874 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_0_.txt
# 2020-09-28 14:28:48,764 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬──────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪══════════╡
# │ 9.7 ± 1.9 │ 0.25 ± 0.18 │ 0.391 ± 0.021 │ 0.08 ± 0.30  │ 122 ± 73 │
# └───────────┴─────────────┴───────────────┴──────────────┴──────────┘
# 2020-09-28 14:28:48,766 - ompy.normalizer_simultan - INFO - Saving to saved_run/normalizers/NormalizerSimultan.pkl

# %%
fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth))
simnorm.plot(ax=ax, add_figlegend=False);
fig.legend(loc=9, ncol=4, frameon=True, fontsize=label_fontsize)
ax[0].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax[0].set_ylabel('Nuclear Level Density (NLD)',fontsize=label_fontsize)
ax[1].set_ylabel('$\gamma SF$',fontsize=label_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('normalized_nld_gsf', dpi=save_dpi)

# %%
normlog = om.introspection.get_logger('normalizer_emsemble_simultan', 'INFO')
ensemblenorm_sim = om.EnsembleNormalizer(extractor=extractor, normalizer_simultan=simnorm, regenerate=regenerator)

ensemblenorm_sim.normalize()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 2020-09-28 14:28:51,588 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 5.484422371241308 │ 0.7494231103759229 │ 0.42016032520764196 │ -0.3755779132980234 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-09-28 14:28:51,604 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬──────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]         │
# ╞═══════════════════╪════════════════════╪═════════════════════╪══════════════════════╡
# │ 7.595091598229247 │ 0.8183847099440122 │ 0.42654975793641753 │ -0.47612276488090816 │
# └───────────────────┴────────────────────┴─────────────────────┴──────────────────────┘
# 2020-09-28 14:28:51,636 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:28:51,642 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┬────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                  │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╪════════════════════╡
# │ 5.484422371241308 │ 0.7494231103759229 │ 0.42016032520764196 │ -0.3755779132980234 │ 24.512700080937908 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┴────────────────────┘
# 2020-09-28 14:28:51,646 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-28 14:28:51,655 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:28:51,666 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬─────────────────────┬──────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]         │ B                 │
# ╞═══════════════════╪════════════════════╪═════════════════════╪══════════════════════╪═══════════════════╡
# │ 7.595091598229247 │ 0.8183847099440122 │ 0.42654975793641753 │ -0.47612276488090816 │ 48.35990371192049 │
# └───────────────────┴────────────────────┴─────────────────────┴──────────────────────┴───────────────────┘
# 2020-09-28 14:28:51,670 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-28 14:28:51,720 - ompy.normalizer_nld - INFO - DE results:
# ┌──────────────────┬───────────────────┬────────────────────┬──────────────────────┐
# │ A                │ α [MeV⁻¹]         │ T [MeV]            │ Eshift [MeV]         │
# ╞══════════════════╪═══════════════════╪════════════════════╪══════════════════════╡
# │ 5.09081720298438 │ 0.715446513394362 │ 0.4086505705513349 │ -0.19666454912023368 │
# └──────────────────┴───────────────────┴────────────────────┴──────────────────────┘
# 2020-09-28 14:28:51,781 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:28:51,787 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌──────────────────┬───────────────────┬────────────────────┬──────────────────────┬────────────────────┐
# │ A                │ α [MeV⁻¹]         │ T [MeV]            │ Eshift [MeV]         │ B                  │
# ╞══════════════════╪═══════════════════╪════════════════════╪══════════════════════╪════════════════════╡
# │ 5.09081720298438 │ 0.715446513394362 │ 0.4086505705513349 │ -0.19666454912023368 │ 3.1295938275748947 │
# └──────────────────┴───────────────────┴────────────────────┴──────────────────────┴────────────────────┘
# 2020-09-28 14:28:51,789 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_2_.txt
# 2020-09-28 14:28:54,909 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬───────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]     │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═══════════════╪═══════════════╪══════════════╪═════════╡
# │ 6.1 ± 1.1 │ 0.261 ± 0.098 │ 0.373 ± 0.011 │ 0.36 ± 0.14  │ 77 ± 23 │
# └───────────┴───────────────┴───────────────┴──────────────┴─────────┘
#   analysing data from multinest/sim_norm_0_.txt
# 2020-09-28 14:28:55,745 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬──────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪══════════╡
# │ 9.7 ± 1.9 │ 0.25 ± 0.18 │ 0.391 ± 0.021 │ 0.08 ± 0.30  │ 122 ± 73 │
# └───────────┴─────────────┴───────────────┴──────────────┴──────────┘
# 2020-09-28 14:28:55,905 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬─────────────────────┬─────────────────────┬──────────────────────┐
# │ A                 │ α [MeV⁻¹]           │ T [MeV]             │ Eshift [MeV]         │
# ╞═══════════════════╪═════════════════════╪═════════════════════╪══════════════════════╡
# │ 16.09477139244435 │ 0.34156344847397263 │ 0.41277458907416903 │ -0.26068087348219005 │
# └───────────────────┴─────────────────────┴─────────────────────┴──────────────────────┘
# 2020-09-28 14:28:55,956 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:28:55,960 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬─────────────────────┬─────────────────────┬──────────────────────┬────────────────────┐
# │ A                 │ α [MeV⁻¹]           │ T [MeV]             │ Eshift [MeV]         │ B                  │
# ╞═══════════════════╪═════════════════════╪═════════════════════╪══════════════════════╪════════════════════╡
# │ 16.09477139244435 │ 0.34156344847397263 │ 0.41277458907416903 │ -0.26068087348219005 │ 20.561143195806313 │
# └───────────────────┴─────────────────────┴─────────────────────┴──────────────────────┴────────────────────┘
# 2020-09-28 14:28:55,962 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_1_.txt
# 2020-09-28 14:28:55,985 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬───────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B         │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═══════════╡
# │ 6.5 ± 1.5 │ 0.23 ± 0.17 │ 0.375 ± 0.014 │ 0.33 ± 0.19  │ 5.8 ± 2.5 │
# └───────────┴─────────────┴───────────────┴──────────────┴───────────┘
# 2020-09-28 14:28:56,844 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬───────────────────┬────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]         │ T [MeV]            │ Eshift [MeV]        │
# ╞═══════════════════╪═══════════════════╪════════════════════╪═════════════════════╡
# │ 6.936816287510347 │ 0.963898393321807 │ 0.4417648337941699 │ -0.7133615970009597 │
# └───────────────────┴───────────────────┴────────────────────┴─────────────────────┘
# 2020-09-28 14:28:56,894 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:28:56,908 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬───────────────────┬────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]         │ T [MeV]            │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪═══════════════════╪════════════════════╪═════════════════════╪═══════════════════╡
# │ 6.936816287510347 │ 0.963898393321807 │ 0.4417648337941699 │ -0.7133615970009597 │ 5.108217498288749 │
# └───────────────────┴───────────────────┴────────────────────┴─────────────────────┴───────────────────┘
# 2020-09-28 14:28:56,910 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-28 14:28:57,123 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞════════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 5.7483025879157115 │ 0.6965461671869584 │ 0.41901813669297483 │ -0.3578555619008542 │
# └────────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-09-28 14:28:57,169 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:28:57,174 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌────────────────────┬────────────────────┬─────────────────────┬─────────────────────┬────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                  │
# ╞════════════════════╪════════════════════╪═════════════════════╪═════════════════════╪════════════════════╡
# │ 5.7483025879157115 │ 0.6965461671869584 │ 0.41901813669297483 │ -0.3578555619008542 │ 2.5342017951089355 │
# └────────────────────┴────────────────────┴─────────────────────┴─────────────────────┴────────────────────┘
# 2020-09-28 14:28:57,175 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_3_.txt
# 2020-09-28 14:28:59,381 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌────────────┬─────────────────┬─────────────────┬───────────────┬─────────┐
# │ A          │ α [MeV⁻¹]       │ T [MeV]         │ Eshift [MeV]  │ B       │
# ╞════════════╪═════════════════╪═════════════════╪═══════════════╪═════════╡
# │ 17.6 ± 1.8 │ 0.0447 ± 0.0066 │ 0.3865 ± 0.0088 │ 0.144 ± 0.097 │ 85 ± 13 │
# └────────────┴─────────────────┴─────────────────┴───────────────┴─────────┘
#   analysing data from multinest/sim_norm_5_.txt
# 2020-09-28 14:28:59,822 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────────┬───────────────┬─────────────────┬───────────────┬───────────┐
# │ A           │ α [MeV⁻¹]     │ T [MeV]         │ Eshift [MeV]  │ B         │
# ╞═════════════╪═══════════════╪═════════════════╪═══════════════╪═══════════╡
# │ 7.09 ± 0.79 │ 0.132 ± 0.035 │ 0.3678 ± 0.0085 │ 0.441 ± 0.095 │ 8.7 ± 1.3 │
# └─────────────┴───────────────┴─────────────────┴───────────────┴───────────┘
#   analysing data from multinest/sim_norm_4_.txt
# 2020-09-28 14:28:59,877 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌────────────┬─────────────┬───────────────┬──────────────┬────────────┐
# │ A          │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B          │
# ╞════════════╪═════════════╪═══════════════╪══════════════╪════════════╡
# │ 11.6 ± 2.2 │ 0.29 ± 0.11 │ 0.390 ± 0.021 │ 0.12 ± 0.31  │ 15.9 ± 6.7 │
# └────────────┴─────────────┴───────────────┴──────────────┴────────────┘
# 2020-09-28 14:29:00,522 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬────────────────────┬──────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │
# ╞═══════════════════╪════════════════════╪════════════════════╪══════════════════════╡
# │ 4.764249919973176 │ 0.9433887153094902 │ 0.4265303308126251 │ -0.47538841343177624 │
# └───────────────────┴────────────────────┴────────────────────┴──────────────────────┘
# 2020-09-28 14:29:00,566 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:29:00,572 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬────────────────────┬──────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │ B                 │
# ╞═══════════════════╪════════════════════╪════════════════════╪══════════════════════╪═══════════════════╡
# │ 4.764249919973176 │ 0.9433887153094902 │ 0.4265303308126251 │ -0.47538841343177624 │ 4.450551768835678 │
# └───────────────────┴────────────────────┴────────────────────┴──────────────────────┴───────────────────┘
# 2020-09-28 14:29:00,574 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-28 14:29:00,881 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬────────────────────┬────────────────────┬─────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │
# ╞════════════════════╪════════════════════╪════════════════════╪═════════════════════╡
# │ 5.5562258445079316 │ 0.8244149186272723 │ 0.4188875662338755 │ -0.3559396288182477 │
# └────────────────────┴────────────────────┴────────────────────┴─────────────────────┘
# 2020-09-28 14:29:00,927 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:29:00,932 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌────────────────────┬────────────────────┬────────────────────┬─────────────────────┬───────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │ B                 │
# ╞════════════════════╪════════════════════╪════════════════════╪═════════════════════╪═══════════════════╡
# │ 5.5562258445079316 │ 0.8244149186272723 │ 0.4188875662338755 │ -0.3559396288182477 │ 84.85503315349384 │
# └────────────────────┴────────────────────┴────────────────────┴─────────────────────┴───────────────────┘
# 2020-09-28 14:29:00,936 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-28 14:29:01,113 - ompy.normalizer_nld - INFO - DE results:
# ┌──────────────────┬────────────────────┬───────────────────┬─────────────────────┐
# │ A                │ α [MeV⁻¹]          │ T [MeV]           │ Eshift [MeV]        │
# ╞══════════════════╪════════════════════╪═══════════════════╪═════════════════════╡
# │ 4.24726009637103 │ 0.8902779889227475 │ 0.420200429974955 │ -0.3763834284484101 │
# └──────────────────┴────────────────────┴───────────────────┴─────────────────────┘
# 2020-09-28 14:29:01,165 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:29:01,169 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌──────────────────┬────────────────────┬───────────────────┬─────────────────────┬───────────────────┐
# │ A                │ α [MeV⁻¹]          │ T [MeV]           │ Eshift [MeV]        │ B                 │
# ╞══════════════════╪════════════════════╪═══════════════════╪═════════════════════╪═══════════════════╡
# │ 4.24726009637103 │ 0.8902779889227475 │ 0.420200429974955 │ -0.3763834284484101 │ 9.337871634167557 │
# └──────────────────┴────────────────────┴───────────────────┴─────────────────────┴───────────────────┘
# 2020-09-28 14:29:01,171 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_7_.txt
# 2020-09-28 14:29:05,856 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬──────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪══════════╡
# │ 7.4 ± 1.6 │ 0.35 ± 0.19 │ 0.387 ± 0.014 │ 0.15 ± 0.23  │ 160 ± 88 │
# └───────────┴─────────────┴───────────────┴──────────────┴──────────┘
#   analysing data from multinest/sim_norm_6_.txt
# 2020-09-28 14:29:05,951 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬───────────────┬───────────────┬──────────────┬────────────┐
# │ A         │ α [MeV⁻¹]     │ T [MeV]       │ Eshift [MeV] │ B          │
# ╞═══════════╪═══════════════╪═══════════════╪══════════════╪════════════╡
# │ 6.8 ± 1.5 │ 0.124 ± 0.038 │ 0.359 ± 0.015 │ 0.54 ± 0.21  │ 16.4 ± 5.8 │
# └───────────┴───────────────┴───────────────┴──────────────┴────────────┘
#   analysing data from multinest/sim_norm_8_.txt
# 2020-09-28 14:29:06,360 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────────┬─────────────┬───────────────┬──────────────┬───────────┐
# │ A           │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B         │
# ╞═════════════╪═════════════╪═══════════════╪══════════════╪═══════════╡
# │ 4.96 ± 0.99 │ 0.68 ± 0.13 │ 0.404 ± 0.018 │ -0.13 ± 0.25 │ 9.7 ± 4.6 │
# └─────────────┴─────────────┴───────────────┴──────────────┴───────────┘
# 2020-09-28 14:29:06,843 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬────────────────────┬──────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │
# ╞═══════════════════╪════════════════════╪════════════════════╪══════════════════════╡
# │ 5.790380176097522 │ 0.5651711398996547 │ 0.4073915183932425 │ -0.17692777857291667 │
# └───────────────────┴────────────────────┴────────────────────┴──────────────────────┘
# 2020-09-28 14:29:06,886 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-28 14:29:06,891 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬────────────────────┬──────────────────────┬────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │ B                  │
# ╞═══════════════════╪════════════════════╪════════════════════╪══════════════════════╪════════════════════╡
# │ 5.790380176097522 │ 0.5651711398996547 │ 0.4073915183932425 │ -0.17692777857291667 │ 1.1512398797913177 │
# └───────────────────┴────────────────────┴────────────────────┴──────────────────────┴────────────────────┘
# 2020-09-28 14:29:06,893 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_9_.txt
# 2020-09-28 14:29:10,646 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B           │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════════╡
# │ 7.4 ± 1.9 │ 0.16 ± 0.12 │ 0.383 ± 0.012 │ 0.21 ± 0.17  │ 2.64 ± 0.63 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────────┘

# %%
fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth+3))
ensemblenorm_sim.plot(ax=ax, n_plot=5, add_figlegend=False)#, random_state=np.random.default_rng(65546645));
fig.legend(loc=9, ncol=4, frameon=True, fontsize=label_fontsize)
ax[0].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax[0].set_ylabel('Level Density $\\rho(E_x)$ $[MeV^{-1}]$',fontsize=label_fontsize)
ax[1].set_ylabel('$\gamma-SF$ $f(E_\gamma)\sim [MeV^{-3}]$',fontsize=label_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
