# %% [markdown]
# Import useful programs

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import ompy as om
import logging

import scipy as sp
from ipywidgets import widgets

from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
print(om.__full_version__)
# Out:
# 1.1.0.dev0+645df2f

# %%
# For reproducability we seed the random generator.
# Note that by default several other classes in ompy, such as all
# classes with multinest calculations have a default seed, too
np.random.seed(1382398)

# %%
# get smaller files for the online version
plt.rcParams["figure.dpi"] = 80

# %%
major_tick_length=12
minor_tick_length=5
tick_width=2
tick_labelsize=22
label_fontsize=22
title_fontsize=22
figwidth=10
figheigth=8
save_dpi = 100


def plot_3D(matrix, filename, xlabel='xlabel', ylabel='ylabel'):
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    matrix.plot(ax=ax);
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(axis='both', which='both', labelsize=tick_labelsize, width=tick_width)
    ax.tick_params(axis='both', which='major', length=major_tick_length)
    ax.tick_params(axis='both', which='minor', length=minor_tick_length)
    ax.set_xlabel(xlabel,fontsize=label_fontsize)
    ax.set_ylabel(ylabel,fontsize=label_fontsize)
    fig.axes[1].tick_params(labelsize=tick_labelsize)
    ax.grid(color='k', linestyle='--', linewidth=.5)
    fig.savefig(filename, dpi=save_dpi)
    
def plot_2D(matrix, filename, projection_axis, xlabel='xlabel', ylabel='ylabel', yscale='log'):
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    matrix.plot_projection(projection_axis, kind="step", ax=ax);
    plt.yscale(yscale)
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(axis='both', which='both', labelsize=tick_labelsize, width=tick_width)
    ax.tick_params(axis='both', which='major', length=major_tick_length)
    ax.tick_params(axis='both', which='minor', length=minor_tick_length)
    ax.set_xlabel(xlabel,fontsize=label_fontsize)
    ax.set_ylabel(ylabel,fontsize=label_fontsize)
    ax.grid(color='k', linestyle='--', linewidth=.5)
    fig.savefig(filename, dpi=save_dpi)

# %%
def plot_matrix(matrix, fig_name, title, scale='log', x_label='$\gamma$-ray energy $E_\gamma$', ylabel='Excitation energy $E_x$'):
    fig, ax = plt.subplots(figsize=(10, 8))
    matrix.plot(ax=ax, scale=scale);
    ax.tick_params(axis='both', labelsize=18)
    ax.set_xlabel('$\gamma$-ray energy $E_\gamma$',fontsize=18)
    ax.set_ylabel('Excitation energy $E_x$',fontsize=18)
    ax.set_title(None)
    fig.suptitle(title, fontsize=20)
    fig.axes[1].tick_params(labelsize=18)
    fig.savefig(fig_name)

# %%
# Import raw matrix into instance of om.Matrix()
#raw = om.Matrix(path="alfna_matrix/alfna_U233")
#raw = om.Matrix(path="alfna_matrix/alfna_right_bg_timecuts")
#raw_fiss = om.Matrix(path="alfna_matrix/alfna_fiss_right_bg_timecuts")

raw = om.Matrix(path="alfna_matrix/alfna_bigger_timecuts")
raw_fiss = om.Matrix(path="alfna_matrix/alfna_fiss_bigger_timecuts")


#Rebin matrices
raw.rebin(0,factor=12)
raw.rebin(1,factor=12)
raw_fiss.rebin(0,factor=12)
raw_fiss.rebin(1,factor=12)

# %%
#plot raw matrix
raw_plot_big = raw.copy()
raw_plot_big.cut('Ex', 0, 8000)
raw_plot_big.cut('Eg', 0, 6000)

Ex = raw_plot_big.Ex
Eg = raw_plot_big.Eg

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
raw_plot_big.plot(ax=ax, vmin=1e-1, vmax=1e2);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot(Eg, Eg, "r--", label="E_x = E_g", linewidth=3.0);
fig.axes[1].tick_params(labelsize=tick_labelsize)

#Plot new diagonal to be used for calibration

#Linefit to calibrate Ex

#finding calibration points alog the diagonal
p0 = [0,0]
p1 = [500, 700]
p2 = [1000, 1200]
p3 = [1500, 1800]
p4 = [2000, 2300]
p5 = [2350, 2600]

#linefit
y_linefit = np.asarray([p0[1], p1[1], p2[1], p3[1], p4[1], p5[1]])
x_linefit = np.asarray([p0[0], p1[0], p2[0], p3[0], p4[0], p5[0]])
z = np.polyfit(x_linefit, y_linefit, 1)
poly = np.poly1d(z)
new_diag = Eg*poly[1] + poly[0]
ax.plot(Eg, new_diag, 'r--', linewidth=3.0);

#finding calibration points alog the diagonal
ax.plot(p0[0], p0[1], 'ko', markersize=7.0);
ax.plot(p1[0], p1[1], 'ko', markersize=7.0);
ax.plot(p2[0], p2[1], 'ko', markersize=7.0);
ax.plot(p3[0], p3[1], 'ko', markersize=7.0);
ax.plot(p4[0], p4[1], 'ko', markersize=7.0);
ax.plot(p5[0], p5[1], 'ko', markersize=7.0);



fig.savefig('plots/raw_uncalibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 1300], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 1300], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.plot([0, 0], [0, 1300], 'r--',linewidth=3.0);
ax.legend(fontsize=label_fontsize, loc='upper left');
fig.savefig('plots/Ex_py_uncalibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw_fiss.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 200], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 200], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=label_fontsize, loc='upper left');
fig.savefig('plots/Ex_py_fiss_uncalibrated', dpi=save_dpi)

# %%
#Calibrate Ex to new diagonal which is decided here
new_diag = raw.Ex*poly[1] + poly[0]

raw.Ex = 2*raw.Ex - new_diag

raw_fiss.Ex = 2*raw_fiss.Ex - new_diag

# %%
#plot raw matrix after calibration

raw_plot_big = raw.copy()
raw_plot_big.cut('Ex', 0, 8000)
raw_plot_big.cut('Eg', 0, 6000)


fig, ax = plt.subplots(figsize=(figwidth, figheigth))
raw_plot_big.plot(ax=ax, vmin=1e-1, vmax=1e2);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
x = np.linspace(0, 6000, len(raw.Ex))
ax.plot(x, x, "r--", label="E_x = E_g", linewidth=3.0);
#ax.plot(x, np.ones(len(raw.Ex))*5550, 'r--'); #fission barrier
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/raw_calibrated', dpi=save_dpi)

#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 1300], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 1300], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.plot([0, 0], [0, 1300], 'r--',linewidth=3.0);
ax.legend(fontsize=16, loc='upper right');
fig.savefig('plots/Ex_py_calibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw_fiss.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 150], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 150], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=16, loc='upper right');
fig.savefig('plots/Ex_py_fiss_calibrated', dpi=save_dpi)

# %%
#Rebin raw matrix
def rebin_cut_raw(raw, kev_per_bin_wish, cut, keep=False):
    """
    Cuts raw matrix Eg and Ex at approximately cut and rebins Eg and Ex with new kev_per_bin_wish
    Cuts away diagonal too
    """
    
    raw_rebin = raw.copy()
    cut = kev_per_bin_wish*round(cut/kev_per_bin_wish)
    raw_rebin.cut('Ex', 0, cut)
    raw_rebin.cut('Eg', 0, cut)
 
    new_mids = np.linspace(kev_per_bin_wish/2, cut-(kev_per_bin_wish/2), int(cut/kev_per_bin_wish))    
    raw_rebin.rebin('Ex', mids=new_mids) #rebinning the Eg energy axis
    raw_rebin.rebin('Eg', mids=new_mids) #rebinning the Ex energy axis
    
    raw_rebin.cut_diagonal(E1=(kev_per_bin_wish, 0), E2 = (cut*2 + kev_per_bin_wish, cut*2))
    
    dEx = raw_rebin.Ex[1] - raw_rebin.Ex[0]
    print('New KeV per bin: %.3f'%dEx)

    #plot matrix
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    raw_rebin.plot(ax=ax, vmin=1e-1, vmax=1e3);
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(axis='both', which='both', labelsize=tick_labelsize, width=tick_width)
    ax.tick_params(axis='both', which='major', length=major_tick_length)
    ax.tick_params(axis='both', which='minor', length=minor_tick_length)
    ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
    ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
    fig.axes[1].tick_params(labelsize=tick_labelsize)
    x = np.linspace(0, cut-kev_per_bin_wish, len(raw.Ex))
    ax.plot(x, x, "r--", label="E_x = E_g", linewidth=3.0);
    ax.grid(color='k', linestyle='--', linewidth=.5)
    fig.savefig('plots/rebinned_matrix', dpi=save_dpi)
    if keep==True:
        return raw_rebin
        #raw=raw_rebin
        #raw.rebin('Ex', mids=new_mids)
        #raw.rebin('Eg', mids=new_mids)
    if keep==False:
        return raw
        
keep = True
raw.save('raw.m')
raw = rebin_cut_raw(raw, kev_per_bin_wish=250, cut=6000, keep=keep)
raw.save('raw_rebinned.m')
# Out:
# New KeV per bin: 250.000

# %% [markdown]
# From the GettingStarted OmPy manual: "Eventhough this experiment was performed with CACTUS, we will now give an example as if the data was taken with OSCAR. This is beacause it is slightly easier to handle. For CACTUS, the response functions do not include the detector threshold; this has do be taken into account separately."
#
# So, I need to include the detector threshold for CACTUS

# %%
### GETTING RESPONSE MATRIX


logger = om.introspection.get_logger('response', 'INFO')
# Then do the same using OMpy functionality:
# You may need to adpot this to whereever you response matrixes are stored
folderpath = "../OCL_response_functions/nai2012_for_opt13"

# Energy calibration of resulting response matrix:
Eg = raw.Eg

# Experimental relative FWHM at 1.33 MeV of resulting array
fwhm_abs = 90.44 # (90/1330 = 6.8%) #CACTUS

response = om.Response(folderpath)
R_ompy_view, R_tab_view = response.interpolate(Eg, fwhm_abs=fwhm_abs, return_table=True)
# Magne recommends 1/10 of the actual resolution for unfolding purposes (see article)
R_ompy_unf, R_tab_unf = response.interpolate(Eg, fwhm_abs=fwhm_abs/10, return_table=True)

R_ompy_view.save("R_ompy_view.m")
R_ompy_unf.save("R_ompy_unf.m")
R_tab_view.to_pickle("R_tab_view.pkl")
R_tab_unf.to_pickle("R_tab_unf.pkl")

# adding response function for CACTUS
fthreshold = sp.interpolate.interp1d([30., 80., 122., 183., 244., 294., 344., 562., 779., 1000.],
                      [0.0, 0.0, 0.0, 0.06, 0.44, 0.60, 0.87, 0.99, 1.00, 1.00],
                      fill_value="extrapolate") #from mama-software ('folding.f')

def apply_detector_threshold(response, table, fthreshold):
    thres = fthreshold(response.Eg)
    response.values = response.values * thres
    # renormalize
    response.values = om.div0(response.values, response.values.sum(axis=1)[:, np.newaxis])
    table["eff_tot"] *= thres

apply_detector_threshold(R_ompy_unf, R_tab_unf, fthreshold)
apply_detector_threshold(R_ompy_view, R_tab_view, fthreshold)


fig, ax = plt.subplots(figsize=(figwidth, figheigth))
R_ompy_view.plot(ax=ax, scale="log", vmin=1e-5, vmax=1e0);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Response Matrix', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/response_matrix', dpi=save_dpi)
# Out:
# 2020-10-12 10:27:57,276 - ompy.response - INFO - Note: Spectra outside of 360.0 and 15000.0 are extrapolation only.
# 2020-10-12 10:27:57,429 - ompy.response - INFO - Note: Spectra outside of 360.0 and 15000.0 are extrapolation only.

# %%
### UNFOLDING

# You can decide to log information and set the logging level (info/debug)
logger = om.introspection.get_logger('unfolder', 'INFO')

# We need to remove negative counts (unphysical) in the raw matrix before unfolding:
raw_positive = raw.copy()
raw_positive.fill_and_remove_negative(window_size=20)
plot_matrix(raw_positive, 'plots/raw_positive_matrix', title='Raw positive matrix')

# With compton subtraction and all tweaks
unfolder = om.Unfolder(response=R_ompy_unf)
unfolder.use_compton_subtraction = True # default
unfolder.response_tab = R_tab_unf
# Magne suggests some "tweaks" for a better unfolding performance. Default is 1 for all.
unfolder.FWHM_tweak_multiplier = {"fe": 1., "se": 1.1,
                                     "de": 1.3, "511": 0.9} #SJEKK DETTE
unfolded = unfolder(raw_positive)

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
unfolded.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e3);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Unfolded', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/unfolded_matrix', dpi=save_dpi)

# %%
### Generate the first generation matrix

firstgen = om.FirstGeneration()
primary = firstgen(unfolded)

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
primary.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e3);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Primary', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/firstgen_matrix', dpi=save_dpi)

# %%
### Propagating statistical uncertainties

logger = om.introspection.get_logger('ensemble', 'INFO')

# Tell the `Ensemble` class which raw spectrum, what kind of unfolder and first
# generations method to use.
# Note: This will have the same setting as above. We could for example have
# set the first generations method to use a different "valley_collection", or a
# differnt type of "multiplicity_estimation"
ensemble = om.Ensemble(raw=raw_positive)
ensemble.unfolder = unfolder
ensemble.first_generation_method = firstgen
# Generates N perturbated members; here just 10 to speed it up
# the `regenerate` flag ensures, that we don't load from disk; which might result in expected results
# if we have changed something in the input `raw` matrix.
ensemble.generate(10, regenerate=True)
# Out:
# 2020-10-12 10:28:00,822 - ompy.ensemble - INFO - Start normalization with 3 cpus
# 2020-10-12 10:28:00,966 - ompy.ensemble - INFO - Generating/loading 0
# 2020-10-12 10:28:00,988 - ompy.ensemble - INFO - Generating/loading 1
# 2020-10-12 10:28:01,051 - ompy.ensemble - INFO - Generating/loading 2
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 2020-10-12 10:28:01,269 - ompy.ensemble - INFO - Generating/loading 3
# 2020-10-12 10:28:01,339 - ompy.ensemble - INFO - Generating/loading 4
# 2020-10-12 10:28:01,484 - ompy.ensemble - INFO - Generating/loading 5
# 2020-10-12 10:28:01,542 - ompy.ensemble - INFO - Generating/loading 6
# 2020-10-12 10:28:01,577 - ompy.ensemble - INFO - Generating/loading 7
# 2020-10-12 10:28:01,704 - ompy.ensemble - INFO - Generating/loading 8
# 2020-10-12 10:28:01,802 - ompy.ensemble - INFO - Generating/loading 9

# %%
#old plotting of unfolded and ensemble
#i_unfolded = 9
#matrix = ensemble.get_unfolded(i_unfolded)
#matrix.plot(title=f"Unfolded matrix #{i_unfolded}")

# Following commands plots all std. deviations
#ensemble.plot();

# %% [markdown]
# Extract Nuclear level density and gamma strength function

# %%
extlog = om.introspection.get_logger('extractor', 'INFO')
trapezoid_cut = om.Action('matrix')
# Trapezoidal cuts
Ex_min = 2000
Ex_max = 5300
Eg_min = 1000
Eg_max = 6000

#plot primary matrix with trapezoidal cuts:
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
primary.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e3);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
# Trapez
x = [Eg_min, Ex_min, Ex_max, Eg_min]
y = [Ex_min, Ex_min, Ex_max, Ex_max]
textstr = '\n'.join((
    r'$E_{x, min}=%.0f$' % (Ex_min, ),
    r'$E_{x, max}=%.0f$' % (Ex_max, ),
    r'$E_{\gamma, min}=%.0f$' % (Eg_min, ),
    r'$E_{\gamma, max}=%.0f$' % (Eg_max, )))
# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
# place a text box in upper left in axes coords
ax.text(.70, 0.25, textstr, transform=ax.transAxes, fontsize=14, verticalalignment='top', bbox=props)

ax.add_patch(patches.Polygon(xy=list(zip(x,y)), fill=False, linewidth=3.0, color='r', linestyle='--'))
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/firstgen_trapezoid', dpi=save_dpi)


#Perform trapezoidal cut
trapezoid_cut.trapezoid(Ex_min=Ex_min, Ex_max=Ex_max, Eg_min=Eg_min, Eg_max = Eg_max, inplace=True)
extractor = om.Extractor()
extractor.trapezoid = trapezoid_cut


E_rebinned = ensemble.get_firstgen(0).Ex
ensemble.rebin(E_rebinned, member="firstgen")

extractor.extract_from(ensemble, regenerate=True)

extractor.plot(scale='log', plot_mean=False);
plt.savefig('unnormed_new_falsemean')

extractor.plot(scale='log', plot_mean=True);
plt.savefig('unnormed_new_truemean')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 2020-10-12 10:28:02,525 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-10-12 10:28:02,526 - ompy.extractor - INFO - Minimizing
# 2020-10-12 10:28:02,807 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-10-12 10:28:02,808 - ompy.extractor - INFO -          Current function value: 296.984352
# 2020-10-12 10:28:02,809 - ompy.extractor - INFO -          Iterations: 4
# 2020-10-12 10:28:02,810 - ompy.extractor - INFO -          Function evaluations: 2206
# 2020-10-12 10:28:02,863 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-10-12 10:28:02,865 - ompy.extractor - INFO - Minimizing
# 2020-10-12 10:28:03,145 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-10-12 10:28:03,146 - ompy.extractor - INFO -          Current function value: 347.144362
# 2020-10-12 10:28:03,147 - ompy.extractor - INFO -          Iterations: 4
# 2020-10-12 10:28:03,148 - ompy.extractor - INFO -          Function evaluations: 2195
# 2020-10-12 10:28:03,200 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-10-12 10:28:03,202 - ompy.extractor - INFO - Minimizing
# 2020-10-12 10:28:03,575 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-10-12 10:28:03,577 - ompy.extractor - INFO -          Current function value: 402.786817
# 2020-10-12 10:28:03,578 - ompy.extractor - INFO -          Iterations: 5
# 2020-10-12 10:28:03,579 - ompy.extractor - INFO -          Function evaluations: 2747
# 2020-10-12 10:28:03,647 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-10-12 10:28:03,649 - ompy.extractor - INFO - Minimizing
# 2020-10-12 10:28:04,096 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-10-12 10:28:04,097 - ompy.extractor - INFO -          Current function value: 401.809983
# 2020-10-12 10:28:04,098 - ompy.extractor - INFO -          Iterations: 5
# 2020-10-12 10:28:04,099 - ompy.extractor - INFO -          Function evaluations: 2780
# 2020-10-12 10:28:04,156 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-10-12 10:28:04,158 - ompy.extractor - INFO - Minimizing
# 2020-10-12 10:28:04,574 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-10-12 10:28:04,575 - ompy.extractor - INFO -          Current function value: 293.498737
# 2020-10-12 10:28:04,576 - ompy.extractor - INFO -          Iterations: 5
# 2020-10-12 10:28:04,578 - ompy.extractor - INFO -          Function evaluations: 2774
# 2020-10-12 10:28:04,628 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-10-12 10:28:04,630 - ompy.extractor - INFO - Minimizing
# 2020-10-12 10:28:04,932 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-10-12 10:28:04,934 - ompy.extractor - INFO -          Current function value: 440.715235
# 2020-10-12 10:28:04,935 - ompy.extractor - INFO -          Iterations: 4
# 2020-10-12 10:28:04,936 - ompy.extractor - INFO -          Function evaluations: 2218
# 2020-10-12 10:28:04,985 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-10-12 10:28:04,987 - ompy.extractor - INFO - Minimizing
# 2020-10-12 10:28:05,310 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-10-12 10:28:05,311 - ompy.extractor - INFO -          Current function value: 368.032072
# 2020-10-12 10:28:05,312 - ompy.extractor - INFO -          Iterations: 4
# 2020-10-12 10:28:05,313 - ompy.extractor - INFO -          Function evaluations: 2198
# 2020-10-12 10:28:05,365 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-10-12 10:28:05,367 - ompy.extractor - INFO - Minimizing
# 2020-10-12 10:28:05,674 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-10-12 10:28:05,675 - ompy.extractor - INFO -          Current function value: 325.196445
# 2020-10-12 10:28:05,676 - ompy.extractor - INFO -          Iterations: 4
# 2020-10-12 10:28:05,677 - ompy.extractor - INFO -          Function evaluations: 2208
# 2020-10-12 10:28:05,728 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-10-12 10:28:05,730 - ompy.extractor - INFO - Minimizing
# 2020-10-12 10:28:06,073 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-10-12 10:28:06,074 - ompy.extractor - INFO -          Current function value: 314.010914
# 2020-10-12 10:28:06,075 - ompy.extractor - INFO -          Iterations: 5
# 2020-10-12 10:28:06,076 - ompy.extractor - INFO -          Function evaluations: 2750
# 2020-10-12 10:28:06,129 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-10-12 10:28:06,130 - ompy.extractor - INFO - Minimizing
# 2020-10-12 10:28:06,464 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-10-12 10:28:06,465 - ompy.extractor - INFO -          Current function value: 455.275197
# 2020-10-12 10:28:06,466 - ompy.extractor - INFO -          Iterations: 5
# 2020-10-12 10:28:06,467 - ompy.extractor - INFO -          Function evaluations: 2746

# %%
# let's remove the nan-valued elements (unconstrained elements) for the further analysis
for nld in extractor.nld:
    nld.cut_nan()

for gsf in extractor.gsf:
    gsf.cut_nan()

# %% [markdown]
# Normalization parameters and explanation:
#
# D0: 4.6 +/- 0.7 Average s-wave resonance spacing D0 [eV] Taken from https://www-nds.iaea.org/RIPL-3/, https://www-nds.iaea.org/cgi-bin/ripl_den_ldp.pl?Z=92&A=233
#
# Sn: Neutron separation energy [MeV] Taken from https://www-nds.iaea.org/RIPL-3/, https://www-nds.iaea.org/cgi-bin/ripl_levels.pl?Z=92&A=233
#
# Spincut pars. Parameters necessary for the spin cut model:
#     NLDa: Level density parameter. Taken from https://journals.aps.org/prc/abstract/10.1103/PhysRevC.80.054310 (Egidy, Bucurescu 2009)
#
#     Eshift: Total backshift parameter. Taken from https://journals.aps.org/prc/abstract/10.1103/PhysRevC.80.054310 (Egidy, Bucurescu 2009)
#
#     sigma2_disc: spin cutoff parameter discrepancy?
#
# Jtarget: 5/2+ “Target” (A-1 nucleus) ground state spin. From https://www-nds.iaea.org/cgi-bin/ripl_levels.pl?Z=92&A=233
#
# nldnorm:
#     limit_low:
#
#     limit_high:
#
# gsfnorm:
#     Gg: Total average radiative width [meV]
#
#
# printout from ompy source-code
#         """ Get the square of the spin cut for a specified model
#
#         if model == "const":
#             pars_req = {"sigma"}
#             return call_model(self.gconst, pars, pars_req)
#         elif model == "EB05":
#             pars_req = {"mass", "NLDa", "Eshift"}
#             return call_model(self.gEB05, pars, pars_req)
#         elif model == "EB09_CT":
#             pars_req = {"mass"}
#             return call_model(self.gEB09_CT, pars, pars_req)
#         elif model == "EB09_emp":
#             pars_req = {"mass", "Pa_prime"}
#             return call_model(self.gEB09_emp, pars, pars_req)
#         elif model == "Disc_and_EB05":
#             pars_req = {"mass", "NLDa", "Eshift", "Sn", "sigma2_disc"}
#             return call_model(self.gDisc_and_EB05, pars, pars_req)
#
# The different spin-cutoff models to use. Which one?

# %%
##Normalization parameters
regenerator = True
def init_normalizers():

    norm_pars = om.NormalizationParameters(name='233U')
    norm_pars.D0 = [4.6, 0.7]  # eV #SJEKK
    norm_pars.Sn = [5.761930, 0] # MeV #SJEKK

    #Which spin-cutoff model to use (uncomment to use):

    #norm_pars.spincutModel = 'Disc_and_EB05'  # see eg. Guttormsen et al., 2017, PRC 96, 024313
    #norm_pars.spincutPars = {"mass":233, "NLDa":25.395, "Eshift":-0.519, "Sn": norm_pars.Sn[0], "sigma2_disc":[1.5, 3.6]}

    #norm_pars.spincutModel = 'EB09_CT'
    #norm_pars.spincutPars = {"mass":233}

    norm_pars.spincutModel = 'EB05'
    norm_pars.spincutPars = {"mass":233, "NLDa":25.395, "Eshift":-0.519}


    norm_pars.Jtarget = 0 # A-1 nucleus (232U)

    # NLD normalizer parameters

    normlog = om.introspection.get_logger('normalizer_nld', 'INFO')
    nldnorm = om.NormalizerNLD(nld=extractor.nld[0], discrete='discrete_levels_U233.txt', regenerate=regenerator)
    nldnorm.smooth_levels_fwhm = 0.1 #0.1 MeV = 100keV is default
    nldnorm.limit_low = [0.2, 0.6]
    nldnorm.limit_high=[1.3, 3.3]

    # gSF normalizer parameters

    normlog = om.introspection.get_logger('normalizer_gsf', 'INFO')
    gsfnorm = om.NormalizerGSF(normalizer_nld=nldnorm, gsf=extractor.gsf[0], regenerate=regenerator)

    # to be used for gsf normalization
    norm_pars.Gg = [30.675, 7.4242]  #meV  Found using a mean value of the Gg values from higher and lower isotopes (RIPL3)

    gsfnorm.model_high.Efit = [3.7, 4.6]
    gsfnorm.model_low.Efit = [1.8, 2.4]


    gsfnorm.norm_pars = norm_pars
    nldnorm.norm_pars = norm_pars
    return nldnorm,gsfnorm

# %% [markdown]
# Simultaneous normalization of the whole ensemble

# %%
def norm_sim(nldnorm, gsfnorm):
    normlog = om.introspection.get_logger('normalizer_simultan', 'INFO')
    simnorm = om.NormalizerSimultan(normalizer_nld=nldnorm, normalizer_gsf=gsfnorm, regenerate=regenerator)
    simnorm.gsf = extractor.gsf[0]
    simnorm.nld = extractor.nld[0]

    # running faster than the default 400 given less precise answers
    # For propper calc. you may rather increase this to > 400.
    simnorm.multinest_kwargs["n_live_points"] = 400
    simnorm.normalize()

    #plot normalization
    fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth))
    simnorm.plot(ax=ax, add_figlegend=False);
    fig.legend(loc=9, ncol=4, frameon=True, fontsize=label_fontsize)
    ax[0].tick_params(axis='both', labelsize=tick_labelsize)
    ax[1].tick_params(axis='both', labelsize=tick_labelsize)
    ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
    ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
    ax[0].set_ylabel('Nuclear Level Density (NLD)',fontsize=label_fontsize)
    ax[1].set_ylabel('$\gamma SF$',fontsize=label_fontsize)
    fig.axes[1].tick_params(labelsize=tick_labelsize)
    fig.savefig('simnorm_nld_gsf', dpi=save_dpi)
    return simnorm, fig

# %%
nldnorm, gsfnorm = init_normalizers()
simnorm, fig = norm_sim(nldnorm, gsfnorm)
# Out:
# 2020-10-12 10:28:11,857 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 4.953294237064249 │ 1.3821079550286097 │ 0.38555285751161694 │ -0.4839287772930466 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-10-12 10:28:11,911 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:28:11,917 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╪═══════════════════╡
# │ 4.953294237064249 │ 1.3821079550286097 │ 0.38555285751161694 │ -0.4839287772930466 │ 36.85551671649278 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┴───────────────────┘
# 2020-10-12 10:28:11,919 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_0_.txt
# 2020-10-12 10:29:53,213 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 5.5 ± 1.2 │ 1.29 ± 0.12 │ 0.384 ± 0.014 │ -0.44 ± 0.22 │ 43 ± 20 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────┘
# 2020-10-12 10:29:53,218 - ompy.normalizer_simultan - INFO - Saving to saved_run/normalizers/NormalizerSimultan.pkl

# %%
nldnorm.normalize()
nldnorm.plot()
gsfnorm.normalize()
gsfnorm.plot()
# Out:
# 2020-10-12 10:29:54,951 - ompy.normalizer_nld - INFO -
#
# ---------
# Normalizing nld #0
# 2020-10-12 10:29:56,397 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 4.953294237064249 │ 1.3821079550286097 │ 0.38555285751161694 │ -0.4839287772930466 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-10-12 10:29:56,398 - ompy.normalizer_nld - INFO - Starting multinest
#   analysing data from multinest/nld_norm_0_.txt
# 2020-10-12 10:30:15,999 - ompy.normalizer_nld - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╡
# │ 5.5 ± 1.2 │ 1.35 ± 0.13 │ 0.388 ± 0.013 │ -0.51 ± 0.21 │
# └───────────┴─────────────┴───────────────┴──────────────┘
# 2020-10-12 10:30:16,000 - ompy.normalizer_nld - INFO - Saving to saved_run/normalizers/NormalizerNLD.pkl
# 2020-10-12 10:30:16,063 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:30:16,068 - ompy.normalizer_gsf - INFO - Saving to saved_run/normalizers/NormalizerGSF.pkl
# (<Figure size 480x320 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f6b7af00a50>)

# %%
def norm_sim_ensemble(nldnorm, gsfnorm):
    normlog = om.introspection.get_logger('normalizer_emsemble_simultan', 'INFO')
    ensemblenorm_sim = om.EnsembleNormalizer(extractor=extractor, normalizer_simultan=simnorm, regenerate=regenerator)
    #ensemblenorm_sim.gsf = extractor.gsf[0]
    #ensemblenorm_sim.nld = extractor.nld[0]
    ensemblenorm_sim.normalize()

    fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth+3))
    ensemblenorm_sim.plot(ax=ax, n_plot=5, add_figlegend=False)#, random_state=np.random.default_rng(65546645));
    fig.legend(loc=9, ncol=4, frameon=True, fontsize=label_fontsize)
    ax[0].tick_params(axis='both', labelsize=tick_labelsize)
    ax[1].tick_params(axis='both', labelsize=tick_labelsize)
    ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
    ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
    ax[0].set_ylabel('Level Density $\\rho(E_x)$ $[MeV^{-1}]$',fontsize=label_fontsize)
    ax[1].set_ylabel('$\gamma-SF$ $f(E_\gamma)\sim [MeV^{-3}]$',fontsize=label_fontsize)
    fig.axes[1].tick_params(labelsize=tick_labelsize)
    fig.savefig('ensemble_simnorm_nld_gsf', dpi=save_dpi)
    return ensemblenorm_sim, fig

# %%
ensemblenorm, fig = norm_sim_ensemble(nldnorm, gsfnorm)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 2020-10-12 10:38:03,391 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬────────────────────┬────────────────────┬─────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │
# ╞════════════════════╪════════════════════╪════════════════════╪═════════════════════╡
# │ 2.8031226696761338 │ 1.6606218851461312 │ 0.3899424631226844 │ -0.5591809172027806 │
# └────────────────────┴────────────────────┴────────────────────┴─────────────────────┘
# 2020-10-12 10:38:03,526 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:38:03,537 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌────────────────────┬────────────────────┬────────────────────┬─────────────────────┬───────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │ B                 │
# ╞════════════════════╪════════════════════╪════════════════════╪═════════════════════╪═══════════════════╡
# │ 2.8031226696761338 │ 1.6606218851461312 │ 0.3899424631226844 │ -0.5591809172027806 │ 15.46768890146832 │
# └────────────────────┴────────────────────┴────────────────────┴─────────────────────┴───────────────────┘
# 2020-10-12 10:38:03,540 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-10-12 10:38:04,591 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 4.953294237064249 │ 1.3821079550286097 │ 0.38555285751161694 │ -0.4839287772930466 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-10-12 10:38:04,700 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬────────────────────┬────────────────────┬─────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │
# ╞════════════════════╪════════════════════╪════════════════════╪═════════════════════╡
# │ 3.2500372284259598 │ 1.5636786262271385 │ 0.3975789547082209 │ -0.6903967122342626 │
# └────────────────────┴────────────────────┴────────────────────┴─────────────────────┘
# 2020-10-12 10:38:04,742 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:38:04,760 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╪═══════════════════╡
# │ 4.953294237064249 │ 1.3821079550286097 │ 0.38555285751161694 │ -0.4839287772930466 │ 36.85551671649278 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┴───────────────────┘
# 2020-10-12 10:38:04,768 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-10-12 10:38:04,883 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:38:04,901 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌────────────────────┬────────────────────┬────────────────────┬─────────────────────┬────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │ B                  │
# ╞════════════════════╪════════════════════╪════════════════════╪═════════════════════╪════════════════════╡
# │ 3.2500372284259598 │ 1.5636786262271385 │ 0.3975789547082209 │ -0.6903967122342626 │ 23.184308457651245 │
# └────────────────────┴────────────────────┴────────────────────┴─────────────────────┴────────────────────┘
# 2020-10-12 10:38:04,907 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_0_.txt
# 2020-10-12 10:39:51,456 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 5.5 ± 1.2 │ 1.29 ± 0.12 │ 0.384 ± 0.014 │ -0.44 ± 0.22 │ 43 ± 20 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────┘
# 2020-10-12 10:39:54,323 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 7.826583787374016 │ 1.2805673897680139 │ 0.38685939564226035 │ -0.5058544992982569 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-10-12 10:39:54,438 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:39:54,446 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╪═══════════════════╡
# │ 7.826583787374016 │ 1.2805673897680139 │ 0.38685939564226035 │ -0.5058544992982569 │ 55.36300937310205 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┴───────────────────┘
# 2020-10-12 10:39:54,451 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_1_.txt
# 2020-10-12 10:40:43,626 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────────┬─────────────┬───────────────┬──────────────┬────────────┐
# │ A           │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B          │
# ╞═════════════╪═════════════╪═══════════════╪══════════════╪════════════╡
# │ 3.17 ± 0.69 │ 1.57 ± 0.12 │ 0.388 ± 0.013 │ -0.51 ± 0.21 │ 17.9 ± 8.8 │
# └─────────────┴─────────────┴───────────────┴──────────────┴────────────┘
# 2020-10-12 10:40:45,108 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬────────────────────┬──────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │
# ╞═══════════════════╪════════════════════╪════════════════════╪══════════════════════╡
# │ 4.447094788158258 │ 1.4626722341798604 │ 0.3855286593908144 │ -0.48313278581385327 │
# └───────────────────┴────────────────────┴────────────────────┴──────────────────────┘
# 2020-10-12 10:40:45,185 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:40:45,191 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬────────────────────┬──────────────────────┬────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │ B                  │
# ╞═══════════════════╪════════════════════╪════════════════════╪══════════════════════╪════════════════════╡
# │ 4.447094788158258 │ 1.4626722341798604 │ 0.3855286593908144 │ -0.48313278581385327 │ 31.617818193803007 │
# └───────────────────┴────────────────────┴────────────────────┴──────────────────────┴────────────────────┘
# 2020-10-12 10:40:45,193 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_2_.txt
# 2020-10-12 10:40:46,685 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A           │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═════════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 3.62 ± 0.77 │ 1.49 ± 0.10 │ 0.397 ± 0.013 │ -0.67 ± 0.20 │ 26 ± 13 │
# └─────────────┴─────────────┴───────────────┴──────────────┴─────────┘
# 2020-10-12 10:40:50,024 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╡
# │ 3.560690466681744 │ 1.4076742399441482 │ 0.3898008061359167 │ -0.5562473100571386 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┘
# 2020-10-12 10:40:50,153 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:40:50,163 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╪═══════════════════╡
# │ 3.560690466681744 │ 1.4076742399441482 │ 0.3898008061359167 │ -0.5562473100571386 │ 33.11958318477048 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┴───────────────────┘
# 2020-10-12 10:40:50,165 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_3_.txt
# 2020-10-12 10:41:38,957 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 8.7 ± 1.9 │ 1.20 ± 0.11 │ 0.385 ± 0.012 │ -0.46 ± 0.19 │ 65 ± 28 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────┘
# 2020-10-12 10:41:40,435 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 3.023134036730749 │ 1.5073584122059103 │ 0.38594403627037605 │ -0.4900344291432964 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-10-12 10:41:40,524 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:41:40,531 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╪═══════════════════╡
# │ 3.023134036730749 │ 1.5073584122059103 │ 0.38594403627037605 │ -0.4900344291432964 │ 32.58916027816554 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┴───────────────────┘
# 2020-10-12 10:41:40,533 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_5_.txt
# 2020-10-12 10:43:01,172 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A           │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═════════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 3.97 ± 0.87 │ 1.33 ± 0.11 │ 0.389 ± 0.013 │ -0.52 ± 0.20 │ 38 ± 18 │
# └─────────────┴─────────────┴───────────────┴──────────────┴─────────┘
# 2020-10-12 10:43:02,772 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 3.647019918667521 │ 1.5760283583719894 │ 0.39356350608942875 │ -0.6209910285931657 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-10-12 10:43:02,891 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:43:02,901 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┬────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                  │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╪════════════════════╡
# │ 3.647019918667521 │ 1.5760283583719894 │ 0.39356350608942875 │ -0.6209910285931657 │ 18.055187367739745 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┴────────────────────┘
# 2020-10-12 10:43:02,907 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_4_.txt
# 2020-10-12 10:43:28,236 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 4.9 ± 1.1 │ 1.38 ± 0.11 │ 0.384 ± 0.012 │ -0.44 ± 0.20 │ 36 ± 17 │
# └───────────┴─────────────┴───────────────┴──────────────┴─────────┘
# 2020-10-12 10:43:31,388 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬───────────┬────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹] │ T [MeV]            │ Eshift [MeV]        │
# ╞═══════════════════╪═══════════╪════════════════════╪═════════════════════╡
# │ 6.061806027709279 │ 0.1       │ 0.9727473678541628 │ -3.1706365716040543 │
# └───────────────────┴───────────┴────────────────────┴─────────────────────┘
# 2020-10-12 10:43:31,391 - ompy.normalizer_nld - WARNING - DE result for alpha is at edge its bound:[0.1, 20]. This will probably leadto wrong estimations in multinest, too.
# 2020-10-12 10:43:31,569 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:43:31,579 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬───────────┬────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹] │ T [MeV]            │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪═══════════╪════════════════════╪═════════════════════╪═══════════════════╡
# │ 6.061806027709279 │ 0.1       │ 0.9727473678541628 │ -3.1706365716040543 │ 61816.40783300477 │
# └───────────────────┴───────────┴────────────────────┴─────────────────────┴───────────────────┘
# 2020-10-12 10:43:31,581 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_6_.txt
# 2020-10-12 10:43:51,758 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A           │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═════════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 3.33 ± 0.71 │ 1.44 ± 0.11 │ 0.385 ± 0.012 │ -0.45 ± 0.19 │ 37 ± 16 │
# └─────────────┴─────────────┴───────────────┴──────────────┴─────────┘
# 2020-10-12 10:43:53,201 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞════════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 3.0460151343380466 │ 1.4482880057408953 │ 0.38189297223188784 │ -0.4201188900031076 │
# └────────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-10-12 10:43:53,345 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-10-12 10:43:53,354 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌────────────────────┬────────────────────┬─────────────────────┬─────────────────────┬────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                  │
# ╞════════════════════╪════════════════════╪═════════════════════╪═════════════════════╪════════════════════╡
# │ 3.0460151343380466 │ 1.4482880057408953 │ 0.38189297223188784 │ -0.4201188900031076 │ 41.139868059033134 │
# └────────────────────┴────────────────────┴─────────────────────┴─────────────────────┴────────────────────┘
# 2020-10-12 10:43:53,360 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_7_.txt
# 2020-10-12 10:45:20,288 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────────┬─────────────┬───────────────┬──────────────┬────────────┐
# │ A           │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B          │
# ╞═════════════╪═════════════╪═══════════════╪══════════════╪════════════╡
# │ 4.03 ± 0.87 │ 1.50 ± 0.11 │ 0.392 ± 0.013 │ -0.58 ± 0.20 │ 20.9 ± 9.7 │
# └─────────────┴─────────────┴───────────────┴──────────────┴────────────┘
#   analysing data from multinest/sim_norm_9_.txt
# 2020-10-12 10:45:47,521 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────────┬─────────────┬───────────────┬──────────────┬─────────┐
# │ A           │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B       │
# ╞═════════════╪═════════════╪═══════════════╪══════════════╪═════════╡
# │ 3.39 ± 0.72 │ 1.37 ± 0.12 │ 0.380 ± 0.013 │ -0.37 ± 0.21 │ 48 ± 22 │
# └─────────────┴─────────────┴───────────────┴──────────────┴─────────┘
#   analysing data from multinest/sim_norm_8_.txt
# 2020-10-12 10:46:30,914 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────────┬───────────────┬───────────────┬──────────────┬──────────┐
# │ A           │ α [MeV⁻¹]     │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞═════════════╪═══════════════╪═══════════════╪══════════════╪══════════╡
# │ 4.95 ± 0.81 │ 0.933 ± 0.068 │ 0.333 ± 0.011 │ 0.46 ± 0.15  │ 229 ± 75 │
# └─────────────┴───────────────┴───────────────┴──────────────┴──────────┘
