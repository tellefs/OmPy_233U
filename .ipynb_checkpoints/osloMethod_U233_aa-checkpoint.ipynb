# %% [markdown]
# Import useful programs

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import ompy as om
import logging

import scipy as sp
#%matplotlib widget
from ipywidgets import widgets #interact, interactive, fixed, interact_manual

from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)

# %%
om.__full_version__;

# %%
# For reproducability we seed the random generator.
# Note that by default several other classes in ompy, such as all
# classes with multinest calculations have a default seed, too
np.random.seed(1382398)

# %%
# get smaller files for the online version
plt.rcParams["figure.dpi"] = 70

# %%
# Import raw matrix into instance of om.Matrix()
raw = om.Matrix(path="alfna_matrix/alfna_U233")

#Rebin raw matrix
raw.rebin(0,factor=12)
raw.rebin(1,factor=12)
raw.plot();

# %%
# Import raw matrix into instance of om.Matrix()
raw_fiss = om.Matrix(path="alfna_matrix/alfna_fiss_U233")

#Rebin raw matrix
raw_fiss.rebin(0,factor=12)
raw_fiss.rebin(1,factor=12)
raw_fiss.plot();

# %%
#New calibration to the theoretical fission barriers

#Fission barrier from RIPL3:

#Empirical HFB Fission barriers:
# Z   N   A  s     Bin     hwin   alphain deltain  Bout   hwout  alphaout deltaout Bout2  hwout2 alphaout2 deltaout2
#                 [MeV]   [MeV] [MeV^-1/2] [MeV]  [MeV]   [MeV] [MeV^-1/2] [MeV]  [MeV]   [MeV] [MeV^-1/2] [MeV]
# 92 142 234 U     5.38    0.66    0.00    0.00    6.15    0.45    0.00    0.00    2.27    0.28    0.00    0.00

#Empirical Barriers:
#  Z   A  s   Syma    Ea     hwa   Symb    Eb     hwb    Deltaf
#                   [MeV]   [MeV]        [MeV]   [MeV]    [MeV]
#  92 232 U     S     4.90    0.90   MA    5.40    0.60    0.848
#  92 233 U     S     4.35    0.80   MA    5.55    0.50    0.946
#  92 234 U     S     4.80    0.90   MA    5.50    0.60    0.8898

# %%
major_tick_length=12
minor_tick_length=5
tick_width=2
tick_labelsize=22
label_fontsize=22
title_fontsize=22
figwidth=10
figheigth=8
save_dpi = 100


def plot_3D(matrix, filename, xlabel='xlabel', ylabel='ylabel'):
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    matrix.plot(ax=ax);
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(axis='both', which='both', labelsize=tick_labelsize, width=tick_width)
    ax.tick_params(axis='both', which='major', length=major_tick_length)
    ax.tick_params(axis='both', which='minor', length=minor_tick_length)
    ax.set_xlabel(xlabel,fontsize=label_fontsize)
    ax.set_ylabel(ylabel,fontsize=label_fontsize)
    fig.axes[1].tick_params(labelsize=tick_labelsize)
    ax.grid(color='k', linestyle='--', linewidth=.5)
    fig.savefig(filename, dpi=save_dpi)
    
def plot_2D(matrix, filename, projection_axis, xlabel='xlabel', ylabel='ylabel', yscale='log'):
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    matrix.plot_projection(projection_axis, kind="step", ax=ax);
    plt.yscale(yscale)
    ax.yaxis.set_minor_locator(AutoMinorLocator())
    ax.xaxis.set_minor_locator(AutoMinorLocator())
    ax.tick_params(axis='both', which='both', labelsize=tick_labelsize, width=tick_width)
    ax.tick_params(axis='both', which='major', length=major_tick_length)
    ax.tick_params(axis='both', which='minor', length=minor_tick_length)
    ax.set_xlabel(xlabel,fontsize=label_fontsize)
    ax.set_ylabel(ylabel,fontsize=label_fontsize)
    ax.grid(color='k', linestyle='--', linewidth=.5)
    fig.savefig(filename, dpi=save_dpi)

# %%
def plot_matrix(matrix, fig_name, title, scale='log', x_label='$\gamma$-ray energy $E_\gamma$', ylabel='Excitation energy $E_x$'):
    fig, ax = plt.subplots(figsize=(10, 8))
    matrix.plot(ax=ax, scale=scale);
    ax.tick_params(axis='both', labelsize=18)
    ax.set_xlabel('$\gamma$-ray energy $E_\gamma$',fontsize=18)
    ax.set_ylabel('Excitation energy $E_x$',fontsize=18)
    ax.set_title(None)
    fig.suptitle(title, fontsize=20)
    fig.axes[1].tick_params(labelsize=18)
    fig.savefig(fig_name)

# %%
#plot raw matrix
raw_plot_big = raw.copy()
raw_plot_big.cut('Ex', 0, 8000)
raw_plot_big.cut('Eg', 0, 6000)

Ex = raw_plot_big.Ex
Eg = raw_plot_big.Eg

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
raw_plot_big.plot(ax=ax);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot(Eg, Eg, "r--", label="E_x = E_g", linewidth=3.0);
#ax.plot(Eg, np.ones(len(Eg))*5550, 'r--'); #fission barrier
fig.axes[1].tick_params(labelsize=tick_labelsize)

#Plot new diagonal to be used for calibration

#Linefit to calibrate Ex

#finding calibration points alog the diagonal
p0 = [0,0]
p1 = [500,700]
p2 = [1000, 1200]
p3 = [1500, 1900]
p4 = [2000, 2300]
p5 = [2500, 3000]

#linefit
y_linefit = np.asarray([p0[1], p1[1], p2[1], p3[1], p4[1]])#, p5[1]])
x_linefit = np.asarray([p0[0], p1[0], p2[0], p3[0], p4[0]])#, p5[0]])
z = np.polyfit(x_linefit, y_linefit, 1)
poly = np.poly1d(z)
new_diag = Eg*poly[1] + poly[0]
ax.plot(Eg, new_diag, 'r--', linewidth=3.0);

#finding calibration points alog the diagonal
ax.plot(p0[0], p0[1], 'ko', markersize=7.0);
ax.plot(p1[0], p1[1], 'ko', markersize=7.0);
ax.plot(p2[0], p2[1], 'ko', markersize=7.0);
ax.plot(p3[0], p3[1], 'ko', markersize=7.0);
ax.plot(p4[0], p4[1], 'ko', markersize=7.0);
#ax.plot(p5[0], p5[1], 'ro');



fig.savefig('plots/raw_uncalibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 1000], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 1000], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=label_fontsize, loc='upper left');
fig.savefig('plots/Ex_py_uncalibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw_fiss.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 400], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 400], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=label_fontsize, loc='upper left');
fig.savefig('plots/Ex_py_fiss_uncalibrated', dpi=save_dpi)

# %%
#Calibrate Ex to new diagonal which is decided here
new_diag = raw.Ex*poly[1] + poly[0]
raw.Ex = 2*raw.Ex - new_diag
raw_fiss.Ex = 2*raw_fiss.Ex - new_diag

# %%
#plot raw matrix after calibration

raw_plot_big = raw.copy()
raw_plot_big.cut('Ex', 0, 8000)
raw_plot_big.cut('Eg', 0, 6000)


fig, ax = plt.subplots(figsize=(figwidth, figheigth))
raw_plot_big.plot(ax=ax);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
x = np.linspace(0, 6000, len(raw.Ex))
ax.plot(x, x, "r--", label="E_x = E_g", linewidth=3.0);
#ax.plot(x, np.ones(len(raw.Ex))*5550, 'r--'); #fission barrier
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/raw_calibrated', dpi=save_dpi)

#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 1000], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 1000], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=label_fontsize, loc='upper left');
fig.savefig('plots/Ex_py_calibrated', dpi=save_dpi)


#plot projection
fig, ax = plt.subplots(figsize=(figwidth, figheigth))
ax.tick_params(axis='both', labelsize=tick_labelsize)
raw_fiss.plot_projection('Ex', Emin=0, Emax=8000, kind="step", ax=ax);
ax.set_ylabel('No. of counts', fontsize=label_fontsize)
ax.set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.plot([5550, 5550], [0, 300], label="Outer fission barrier \n at $5.55MeV$", linewidth=3.0);
ax.plot([4350, 4350], [0, 300], 'g--', label="Inner fission barrier \n at $4.35MeV$", linewidth=3.0);
ax.legend(fontsize=label_fontsize, loc='upper left');
fig.savefig('plots/Ex_py_fiss_calibrated', dpi=save_dpi)

# %%
#Rebin raw matrix

def rebin_raw(raw, kev_per_bin_wish, keep=False):
    raw_rebin = raw.copy()
    raw_rebin.cut('Ex', 0, 10000)
    raw_rebin.cut('Eg', 0, 10000)
    kev_per_bin = abs(raw_rebin.Eg[0]-raw_rebin.Eg[1])
    rebin_factor = kev_per_bin_wish/kev_per_bin
    raw_rebin.rebin(0, factor=rebin_factor) #rebinning the Eg energy axis
    raw_rebin.rebin(1, factor=rebin_factor) #rebinning the Ex energy axis
    plot_3D(raw_rebin, 'plots/rebinned_matrix', xlabel='$\gamma$-ray energy $E_\gamma$ [keV]', ylabel='Excitation energy $E_x$ [keV]')
    if keep==True:
        raw.rebin(0, factor=rebin_factor)

        
rebin_raw(raw, 128., keep=True) #Talked with Magne about putting 128keV/bin

# %%
# Cut away counts above the diagonal
# Remember: Think about what you do here. If you cut them away, they will not
# be used in unfolding etc. This may or may not be what you want.

raw.cut_diagonal(E1=(200, 0), E2=(7700, 7500))
raw.cut('Ex', 0, 6000)
raw.cut('Eg', 0, 6000)


plot_matrix(raw, 'plots/raw_diag_cut', title='Raw matrix after calibrations and diagonal cut')
fig, ax = plt.subplots(figsize=(10, 8))
raw.plot_projection('Eg',ax=ax);

# %% [markdown]
# From the GettingStarted OmPy manual: "Eventhough this experiment was performed with CACTUS, we will now give an example as if the data was taken with OSCAR. This is beacause it is slightly easier to handle. For CACTUS, the response functions do not include the detector threshold; this has do be taken into account separately."
#
# So, I need to include the detector threshold for CACTUS

# %%
### GETTING RESPONSE MATRIX


logger = om.introspection.get_logger('response', 'INFO')
# Then do the same using OMpy functionality:
# You may need to adpot this to whereever you response matrixes are stored
folderpath = "../OCL_response_functions/nai2012_for_opt13"

# Energy calibration of resulting response matrix:
Eg = raw.Eg

# Experimental relative FWHM at 1.33 MeV of resulting array
#fwhm_abs = 30 # (30/1330 = 2.25% ) #LaBr
fwhm_abs = 90.44 # (90/1330 = 6.8%) #CACTUS


response = om.Response(folderpath)
R_ompy_view, R_tab_view = response.interpolate(Eg, fwhm_abs=fwhm_abs, return_table=True)
# Magne recommends 1/10 of the actual resolution for unfolding purposes (see article)
R_ompy_unf, R_tab_unf = response.interpolate(Eg, fwhm_abs=fwhm_abs/10, return_table=True)

R_ompy_view.save("R_ompy_view.m")
R_ompy_unf.save("R_ompy_unf.m")
R_tab_view.to_pickle("R_tab_view.pkl")
R_tab_unf.to_pickle("R_tab_unf.pkl")
# Out:
# 2020-09-08 14:28:48,263 - ompy.response - INFO - Note: Spectra outside of 360.0 and 15000.0 are extrapolation only.
# 2020-09-08 14:28:48,533 - ompy.response - INFO - Note: Spectra outside of 360.0 and 15000.0 are extrapolation only.

# %%
# adding response function for CACTUS

fthreshold = sp.interpolate.interp1d([30., 80., 122., 183., 244., 294., 344., 562., 779., 1000.],
                      [0.0, 0.0, 0.0, 0.06, 0.44, 0.60, 0.87, 0.99, 1.00, 1.00],
                      fill_value="extrapolate") #from mama-software ('folding.f')

def apply_detector_threshold(response, table, fthreshold):
    thres = fthreshold(response.Eg)
    response.values = response.values * thres
    # renormalize
    response.values = om.div0(response.values, response.values.sum(axis=1)[:, np.newaxis])
    table["eff_tot"] *= thres

apply_detector_threshold(R_ompy_unf, R_tab_unf, fthreshold)
apply_detector_threshold(R_ompy_view, R_tab_view, fthreshold)


fig, ax = plt.subplots(figsize=(figwidth, figheigth))
R_ompy_view.plot(ax=ax, scale="log", vmin=1e-5, vmax=1e0);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Response Matrix', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/response_matrix', dpi=save_dpi)

# %%
### UNFOLDING

# You can decide to log information and set the logging level (info/debug)
logger = om.introspection.get_logger('unfolder', 'INFO')

# We need to remove negative counts (unphysical) in the raw matrix before unfolding:
raw_positive = raw.copy()
raw_positive.fill_and_remove_negative(window_size=20)
plot_matrix(raw_positive, 'plots/raw_positive_matrix', title='Raw positive matrix')

# With compton subtraction and all tweaks
unfolder = om.Unfolder(response=R_ompy_unf)
unfolder.use_compton_subtraction = True # default
unfolder.response_tab = R_tab_unf
# Magne suggests some "tweaks" for a better unfolding performance. Default is 1 for all.
unfolder.FWHM_tweak_multiplier = {"fe": 1., "se": 1.1,
                                     "de": 1.3, "511": 0.9} #SJEKK DETTE
unfolded = unfolder(raw_positive)

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
unfolded.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e3);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Unfolded', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/unfolded_matrix', dpi=save_dpi)

# %%
### Generate the first generation matrix

firstgen = om.FirstGeneration()
primary = firstgen(unfolded)

fig, ax = plt.subplots(figsize=(figwidth, figheigth))
primary.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e2);
ax.tick_params(axis='both', labelsize=tick_labelsize)
ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax.set_title('Primary', size=title_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
fig.savefig('plots/firstgen_matrix', dpi=save_dpi)

# %%
### Propagating statistical uncertainties

logger = om.introspection.get_logger('ensemble', 'INFO')

# Tell the `Ensemble` class which raw spectrum, what kind of unfolder and first
# generations method to use.
# Note: This will have the same setting as above. We could for example have
# set the first generations method to use a different "valley_collection", or a
# differnt type of "multiplicity_estimation"
ensemble = om.Ensemble(raw=raw_positive)
ensemble.unfolder = unfolder
ensemble.first_generation_method = firstgen
# Generates N perturbated members; here just 10 to speed it up
# the `regenerate` flag ensures, that we don't load from disk; which might result in expected results
# if we have changed something in the input `raw` matrix.
ensemble.generate(10, regenerate=True)
# Out:
# 2020-09-08 14:28:51,666 - ompy.ensemble - INFO - Start normalization with 3 cpus
# 2020-09-08 14:28:51,720 - ompy.ensemble - INFO - Generating/loading 0
# 2020-09-08 14:28:51,738 - ompy.ensemble - INFO - Generating/loading 1
# 2020-09-08 14:28:51,758 - ompy.ensemble - INFO - Generating/loading 2
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 2020-09-08 14:28:52,087 - ompy.ensemble - INFO - Generating/loading 3
# 2020-09-08 14:28:52,106 - ompy.ensemble - INFO - Generating/loading 4
# 2020-09-08 14:28:52,142 - ompy.ensemble - INFO - Generating/loading 5
# 2020-09-08 14:28:52,435 - ompy.ensemble - INFO - Generating/loading 6
# 2020-09-08 14:28:52,460 - ompy.ensemble - INFO - Generating/loading 7
# 2020-09-08 14:28:52,516 - ompy.ensemble - INFO - Generating/loading 8
# 2020-09-08 14:28:52,791 - ompy.ensemble - INFO - Generating/loading 9

# %%
#i_unfolded = 9
#matrix = ensemble.get_unfolded(i_unfolded)
#matrix.plot(title=f"Unfolded matrix #{i_unfolded}")

# Following commands plots all std. deviations
#ensemble.plot();

# %% [markdown]
# Extract Nuclear level density and gamma strength function

# %%
extlog = om.introspection.get_logger('extractor', 'INFO')
trapezoid_cut = om.Action('matrix')
# Trapezoidal cuts
Ex_min_list = [2000]#[1500, 2000]
Ex_max_list = [4800]#[4300, 4800, 5000]
Eg_min_list = [1200]#[1200, 1500]
Eg_max_list = [6000+200]

def plot_primary_w_trapez(primary, Ex_min, Ex_max, Eg_min, Eg_max, save=False):
    #plot primary matrix with trapezoidal cuts:
    fig, ax = plt.subplots(figsize=(figwidth, figheigth))
    primary.plot(ax=ax, scale="log", vmin=1e-1, vmax=1e2);
    ax.tick_params(axis='both', labelsize=tick_labelsize)
    ax.set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
    ax.set_ylabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
    # Trapez
    x = [Eg_min, Ex_min+200, Ex_max+200, Eg_min]
    y = [Ex_min, Ex_min, Ex_max, Ex_max]
    textstr = '\n'.join((
        r'$E_{x, min}=%.0f$' % (Ex_min, ),
        r'$E_{x, max}=%.0f$' % (Ex_max, ),
        r'$E_{\gamma, min}=%.0f$' % (Eg_min, ),
        r'$E_{\gamma, max}=%.0f$' % (Eg_max, )))
    # these are matplotlib.patch.Patch properties
    props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
    # place a text box in upper left in axes coords
    ax.text(.70, 0.25, textstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)

    ax.add_patch(patches.Polygon(xy=list(zip(x,y)), fill=False, linewidth=3.0, color='r', linestyle='--'))
    fig.axes[1].tick_params(labelsize=tick_labelsize)
    if(save==True):
        fig.savefig('plots/firstgen_trapezoid', dpi=save_dpi)

# %%
plot_nld_gfs = True
for Ex_min in Ex_min_list:
    for Ex_max in Ex_max_list:
        for Eg_min in Eg_min_list:
            for Eg_max in Eg_max_list:
                if Eg_min<=Ex_min:
                    plot_primary_w_trapez(primary, Ex_min, Ex_max, Eg_min, Eg_max)

                    trapezoid_cut.trapezoid(Ex_min=Ex_min, Ex_max=Ex_max, Eg_min=Eg_min, inplace=True)
                    extractor = om.Extractor()
                    extractor.trapezoid = trapezoid_cut
                    E_rebinned = np.arange(0, 6500, 200.) #RIKTIG BINNING?
                    ensemble.rebin(E_rebinned, member="firstgen")
                    extractor.extract_from(ensemble, regenerate=True)
                    if plot_nld_gfs == True:
                        fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth))
                        extractor.plot(ax=ax, scale='log', plot_mean=False);
                        ax[0].tick_params(axis='both', labelsize=tick_labelsize)
                        ax[1].tick_params(axis='both', labelsize=tick_labelsize)
                        ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
                        ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
                        ax[0].set_ylabel('Nuclear Level Density (NLD)',fontsize=label_fontsize)
                        ax[1].set_ylabel('$\gamma SF$',fontsize=label_fontsize)
                        fig.axes[1].tick_params(labelsize=tick_labelsize)


                        fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth))
                        extractor.plot(ax=ax, scale='log', plot_mean=True);
                        ax[0].tick_params(axis='both', labelsize=tick_labelsize)
                        ax[1].tick_params(axis='both', labelsize=tick_labelsize)
                        ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
                        ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
                        ax[0].set_ylabel('Nuclear Level Density (NLD)',fontsize=label_fontsize)
                        ax[1].set_ylabel('$\gamma SF$',fontsize=label_fontsize)
                        fig.axes[1].tick_params(labelsize=tick_labelsize)
                        
                        
                        
Ex_min_list = [2000]#[1500, 2000]
Ex_max_list = [4800]#[4300, 4800, 5000]
Eg_min_list = [1200]#[1200, 1500]
Eg_max_list = [6000+200]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 2020-09-08 14:30:10,673 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-08 14:30:10,675 - ompy.extractor - INFO - Minimizing
# 2020-09-08 14:30:10,815 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-08 14:30:10,815 - ompy.extractor - INFO -          Current function value: 471.454563
# 2020-09-08 14:30:10,816 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-08 14:30:10,816 - ompy.extractor - INFO -          Function evaluations: 2372
# 2020-09-08 14:30:10,847 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-08 14:30:10,848 - ompy.extractor - INFO - Minimizing
# 2020-09-08 14:30:11,014 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-08 14:30:11,015 - ompy.extractor - INFO -          Current function value: 394.590586
# 2020-09-08 14:30:11,016 - ompy.extractor - INFO -          Iterations: 5
# 2020-09-08 14:30:11,016 - ompy.extractor - INFO -          Function evaluations: 2958
# 2020-09-08 14:30:11,045 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-08 14:30:11,046 - ompy.extractor - INFO - Minimizing
# 2020-09-08 14:30:11,183 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-08 14:30:11,183 - ompy.extractor - INFO -          Current function value: 385.513500
# 2020-09-08 14:30:11,184 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-08 14:30:11,185 - ompy.extractor - INFO -          Function evaluations: 2393
# 2020-09-08 14:30:11,313 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-08 14:30:11,314 - ompy.extractor - INFO - Minimizing
# 2020-09-08 14:30:11,449 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-08 14:30:11,449 - ompy.extractor - INFO -          Current function value: 437.442170
# 2020-09-08 14:30:11,450 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-08 14:30:11,451 - ompy.extractor - INFO -          Function evaluations: 2364
# 2020-09-08 14:30:11,479 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-08 14:30:11,480 - ompy.extractor - INFO - Minimizing
# 2020-09-08 14:30:11,612 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-08 14:30:11,613 - ompy.extractor - INFO -          Current function value: 416.811810
# 2020-09-08 14:30:11,614 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-08 14:30:11,614 - ompy.extractor - INFO -          Function evaluations: 2371
# 2020-09-08 14:30:11,643 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-08 14:30:11,643 - ompy.extractor - INFO - Minimizing
# 2020-09-08 14:30:11,776 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-08 14:30:11,777 - ompy.extractor - INFO -          Current function value: 501.483595
# 2020-09-08 14:30:11,778 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-08 14:30:11,779 - ompy.extractor - INFO -          Function evaluations: 2355
# 2020-09-08 14:30:11,808 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-08 14:30:11,809 - ompy.extractor - INFO - Minimizing
# 2020-09-08 14:30:11,948 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-08 14:30:11,949 - ompy.extractor - INFO -          Current function value: 435.340034
# 2020-09-08 14:30:11,950 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-08 14:30:11,951 - ompy.extractor - INFO -          Function evaluations: 2373
# 2020-09-08 14:30:12,046 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-08 14:30:12,047 - ompy.extractor - INFO - Minimizing
# 2020-09-08 14:30:12,187 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-08 14:30:12,188 - ompy.extractor - INFO -          Current function value: 389.242190
# 2020-09-08 14:30:12,188 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-08 14:30:12,189 - ompy.extractor - INFO -          Function evaluations: 2374
# 2020-09-08 14:30:12,218 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-08 14:30:12,219 - ompy.extractor - INFO - Minimizing
# 2020-09-08 14:30:12,354 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-08 14:30:12,355 - ompy.extractor - INFO -          Current function value: 404.539325
# 2020-09-08 14:30:12,356 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-08 14:30:12,357 - ompy.extractor - INFO -          Function evaluations: 2362
# 2020-09-08 14:30:12,386 - ompy.extractor - INFO - Infering calibration that calibration is in keV.
# 2020-09-08 14:30:12,387 - ompy.extractor - INFO - Minimizing
# 2020-09-08 14:30:12,524 - ompy.extractor - INFO - Optimization terminated successfully.
# 2020-09-08 14:30:12,525 - ompy.extractor - INFO -          Current function value: 438.079862
# 2020-09-08 14:30:12,526 - ompy.extractor - INFO -          Iterations: 4
# 2020-09-08 14:30:12,526 - ompy.extractor - INFO -          Function evaluations: 2362

# %%
fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth))
extractor.plot(ax=ax, scale='log', plot_mean=False);
ax[0].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax[0].set_ylabel('Nuclear Level Density (NLD)',fontsize=label_fontsize)
ax[1].set_ylabel('$\gamma SF$',fontsize=label_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)


fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth))
extractor.plot(ax=ax, scale='log', plot_mean=True);
ax[0].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax[0].set_ylabel('Nuclear Level Density (NLD)',fontsize=label_fontsize)
ax[1].set_ylabel('$\gamma SF$',fontsize=label_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)

# %%
# let's remove the nan-valued elements (unconstrained elements) for the further analysis
for nld in extractor.nld:
    nld.cut_nan()

for gsf in extractor.gsf:
    gsf.cut_nan()

# %% [markdown]
# Normalization parameters and explanation:
#
# D0: 4.6 +/- 0.7 Average s-wave resonance spacing D0 [eV] Taken from https://www-nds.iaea.org/RIPL-3/, https://www-nds.iaea.org/cgi-bin/ripl_den_ldp.pl?Z=92&A=233
#
# Sn: Neutron separation energy [MeV] Taken from https://www-nds.iaea.org/RIPL-3/, https://www-nds.iaea.org/cgi-bin/ripl_levels.pl?Z=92&A=233
#
# Spincut pars. Parameters necessary for the spin cut model:
#     NLDa: Level density parameter. Taken from https://journals.aps.org/prc/abstract/10.1103/PhysRevC.80.054310 (Egidy, Bucurescu 2009)
#
#     Eshift: Total backshift parameter. Taken from https://journals.aps.org/prc/abstract/10.1103/PhysRevC.80.054310 (Egidy, Bucurescu 2009)
#
#     sigma2_disc: spin cutoff parameter discrepancy?
#
# Jtarget: 5/2+ “Target” (A-1 nucleus) ground state spin. From https://www-nds.iaea.org/cgi-bin/ripl_levels.pl?Z=92&A=233
#
# nldnorm:
#     limit_low:
#
#     limit_high:
#
# gsfnorm:
#     Gg: Total average radiative width [meV]

# %%
#Normalization parameters

regenerator = True

norm_pars = om.NormalizationParameters(name='233U')
norm_pars.D0 = [4.6, 0.7]  # eV #SJEKK
norm_pars.Sn = [5.761930, 0] # MeV #SJEKK
norm_pars.spincutModel = 'Disc_and_EB05'  # see eg. Guttormsen et al., 2017, PRC 96, 024313
#SJEKK ALLE DISSE
norm_pars.spincutPars = {"mass":233, "NLDa":23.23, "Eshift":-0.33,
                         "Sn": norm_pars.Sn[0], "sigma2_disc":[1.5, 3.6]}
norm_pars.Jtarget = 5/2 # A-1 nucleus

# %%
# NLD normalizer parameters

normlog = om.introspection.get_logger('normalizer_nld', 'INFO')
nldnorm = om.NormalizerNLD(nld=extractor.nld[0], discrete='discrete_levels_U233.txt', regenerate=regenerator)
nldnorm.limit_low = [0, 0.5]
nldnorm.limit_high=[2.0, 3.5]
nldnorm.norm_pars = norm_pars

# %%
# gSF normalizer parameters

normlog = om.introspection.get_logger('normalizer_gsf', 'INFO')
gsfnorm = om.NormalizerGSF(normalizer_nld=nldnorm, gsf=extractor.gsf[0], regenerate=regenerator)

# to be used for gsf normalization
#SJEKK
norm_pars.Gg = [30.675, 7.4242]  #meV  Found using a mean value of the Gg values from higher and lower isotopes (RIPL3)

gsfnorm.norm_pars = norm_pars
gsfnorm.model_high.Efit = [3.5, 4.5]

# %%
nldnorm.normalize(limit_low = nldnorm.limit_low, limit_high=nldnorm.limit_high, norm_pars=norm_pars)
# Out:
# 2020-09-07 15:53:55,610 - ompy.normalizer_nld - INFO -
#
# ---------
# Normalizing nld #0
# 2020-09-07 15:53:56,433 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬───────────────────┬────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]         │ T [MeV]            │ Eshift [MeV]        │
# ╞═══════════════════╪═══════════════════╪════════════════════╪═════════════════════╡
# │ 9.068475088275788 │ 0.567759639194993 │ 0.4140627120771629 │ -0.2702965064754938 │
# └───────────────────┴───────────────────┴────────────────────┴─────────────────────┘
# 2020-09-07 15:53:56,434 - ompy.normalizer_nld - INFO - Starting multinest
#   analysing data from multinest/nld_norm_0_.txt
# 2020-09-07 15:54:13,095 - ompy.normalizer_nld - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╡
# │ 9.7 ± 1.7 │ 0.52 ± 0.14 │ 0.413 ± 0.021 │ -0.23 ± 0.31 │
# └───────────┴─────────────┴───────────────┴──────────────┘
# 2020-09-07 15:54:13,096 - ompy.normalizer_nld - INFO - Saving to saved_run/normalizers/NormalizerNLD.pkl

# %%
gsfnorm.normalize()
# Out:
# 2020-09-07 15:54:14,390 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:14,395 - ompy.normalizer_gsf - INFO - Saving to saved_run/normalizers/NormalizerGSF.pkl

# %% [markdown]
# Simultaneous normalization of the whole ensemble

# %%
normlog = om.introspection.get_logger('normalizer_simultan', 'INFO')
simnorm = om.NormalizerSimultan(normalizer_nld=nldnorm, normalizer_gsf=gsfnorm, regenerate=regenerator)
simnorm.gsf = extractor.gsf[0]
simnorm.nld = extractor.nld[0]

# running faster than the default 400 given less precise answers
# For propper calc. you may rather increase this to > 400.
simnorm.multinest_kwargs["n_live_points"] = 10
simnorm.normalize()
# Out:
# 2020-09-07 15:54:17,483 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 9.068485022225593 │ 0.5677665738906886 │ 0.41406698964030575 │ -0.2703524038565183 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-09-07 15:54:17,520 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:17,523 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┬──────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╪══════════════════╡
# │ 9.068485022225593 │ 0.5677665738906886 │ 0.41406698964030575 │ -0.2703524038565183 │ 83.2731204014311 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┴──────────────────┘
# 2020-09-07 15:54:17,524 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_0_.txt
# 2020-09-07 15:54:19,948 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌────────────┬───────────────┬─────────────────┬──────────────┬──────────┐
# │ A          │ α [MeV⁻¹]     │ T [MeV]         │ Eshift [MeV] │ B        │
# ╞════════════╪═══════════════╪═════════════════╪══════════════╪══════════╡
# │ 10.2 ± 1.2 │ 0.187 ± 0.064 │ 0.3544 ± 0.0084 │ 0.70 ± 0.11  │ 351 ± 78 │
# └────────────┴───────────────┴─────────────────┴──────────────┴──────────┘
# 2020-09-07 15:54:19,951 - ompy.normalizer_simultan - INFO - Saving to saved_run/normalizers/NormalizerSimultan.pkl

# %%
fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth))
simnorm.plot(ax=ax, add_figlegend=False);
fig.legend(loc=9, ncol=4, frameon=True, fontsize=label_fontsize)
ax[0].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax[0].set_ylabel('Nuclear Level Density (NLD)',fontsize=label_fontsize)
ax[1].set_ylabel('$\gamma SF$',fontsize=label_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)

# %%
normlog = om.introspection.get_logger('normalizer_emsemble_simultan', 'INFO')
ensemblenorm_sim = om.EnsembleNormalizer(extractor=extractor, normalizer_simultan=simnorm, regenerate=regenerator)

ensemblenorm_sim.normalize()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# 2020-09-07 15:54:39,841 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╡
# │ 6.420277427607579 │ 0.8673577463573535 │ 0.4405687484528867 │ -0.6830442401334393 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┘
# 2020-09-07 15:54:39,848 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╡
# │ 8.993590575081523 │ 0.5708573859019722 │ 0.4140636220622257 │ -0.2705782462324812 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┘
# 2020-09-07 15:54:39,893 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:39,899 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╪═══════════════════╡
# │ 6.420277427607579 │ 0.8673577463573535 │ 0.4405687484528867 │ -0.6830442401334393 │ 60.69866171008839 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┴───────────────────┘
# 2020-09-07 15:54:39,901 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-07 15:54:39,899 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:39,914 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪════════════════════╪════════════════════╪═════════════════════╪═══════════════════╡
# │ 8.993590575081523 │ 0.5708573859019722 │ 0.4140636220622257 │ -0.2705782462324812 │ 83.38954254139236 │
# └───────────────────┴────────────────────┴────────────────────┴─────────────────────┴───────────────────┘
# 2020-09-07 15:54:39,917 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-07 15:54:40,171 - ompy.normalizer_nld - INFO - DE results:
# ┌──────────────────┬────────────────────┬────────────────────┬──────────────────────┐
# │ A                │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │
# ╞══════════════════╪════════════════════╪════════════════════╪══════════════════════╡
# │ 7.99134670147461 │ 0.7162049574883345 │ 0.4011751437156129 │ -0.06966796116198416 │
# └──────────────────┴────────────────────┴────────────────────┴──────────────────────┘
# 2020-09-07 15:54:40,217 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:40,223 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌──────────────────┬────────────────────┬────────────────────┬──────────────────────┬───────────────────┐
# │ A                │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │ B                 │
# ╞══════════════════╪════════════════════╪════════════════════╪══════════════════════╪═══════════════════╡
# │ 7.99134670147461 │ 0.7162049574883345 │ 0.4011751437156129 │ -0.06966796116198416 │ 279.7518360294014 │
# └──────────────────┴────────────────────┴────────────────────┴──────────────────────┴───────────────────┘
# 2020-09-07 15:54:40,227 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_1_.txt
# 2020-09-07 15:54:42,597 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────┬───────────────┬───────────────┬──────────────┬──────────┐
# │ A       │ α [MeV⁻¹]     │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞═════════╪═══════════════╪═══════════════╪══════════════╪══════════╡
# │ 19 ± 13 │ 0.141 ± 0.033 │ 0.351 ± 0.023 │ 0.94 ± 0.45  │ 107 ± 45 │
# └─────────┴───────────────┴───────────────┴──────────────┴──────────┘
#   analysing data from multinest/sim_norm_0_.txt
# 2020-09-07 15:54:42,961 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌────────────┬─────────────┬───────────────┬──────────────┬──────────┐
# │ A          │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞════════════╪═════════════╪═══════════════╪══════════════╪══════════╡
# │ 10.7 ± 1.1 │ 0.43 ± 0.11 │ 0.400 ± 0.015 │ -0.05 ± 0.25 │ 114 ± 66 │
# └────────────┴─────────────┴───────────────┴──────────────┴──────────┘
#   analysing data from multinest/sim_norm_2_.txt
# 2020-09-07 15:54:43,457 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌────────────┬───────────────┬───────────────┬──────────────┬────────────┐
# │ A          │ α [MeV⁻¹]     │ T [MeV]       │ Eshift [MeV] │ B          │
# ╞════════════╪═══════════════╪═══════════════╪══════════════╪════════════╡
# │ 10.5 ± 1.2 │ 0.183 ± 0.072 │ 0.331 ± 0.011 │ 1.05 ± 0.15  │ 1079 ± 389 │
# └────────────┴───────────────┴───────────────┴──────────────┴────────────┘
# 2020-09-07 15:54:43,566 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬────────────────────┬──────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │
# ╞═══════════════════╪════════════════════╪════════════════════╪══════════════════════╡
# │ 4.707824456618009 │ 0.9336611764333111 │ 0.4109993155362723 │ -0.22329312688004282 │
# └───────────────────┴────────────────────┴────────────────────┴──────────────────────┘
# 2020-09-07 15:54:43,607 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:43,612 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬────────────────────┬──────────────────────┬────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │ B                  │
# ╞═══════════════════╪════════════════════╪════════════════════╪══════════════════════╪════════════════════╡
# │ 4.707824456618009 │ 0.9336611764333111 │ 0.4109993155362723 │ -0.22329312688004282 │ 109.51842995386595 │
# └───────────────────┴────────────────────┴────────────────────┴──────────────────────┴────────────────────┘
# 2020-09-07 15:54:43,614 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-07 15:54:43,994 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬────────────────────┬──────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │
# ╞═══════════════════╪════════════════════╪════════════════════╪══════════════════════╡
# │ 5.756201628132201 │ 0.8333135375122743 │ 0.3928565327026096 │ 0.060198725692780834 │
# └───────────────────┴────────────────────┴────────────────────┴──────────────────────┘
# 2020-09-07 15:54:44,036 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:44,040 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬────────────────────┬──────────────────────┬────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │ B                  │
# ╞═══════════════════╪════════════════════╪════════════════════╪══════════════════════╪════════════════════╡
# │ 5.756201628132201 │ 0.8333135375122743 │ 0.3928565327026096 │ 0.060198725692780834 │ 160.71032893922592 │
# └───────────────────┴────────────────────┴────────────────────┴──────────────────────┴────────────────────┘
# 2020-09-07 15:54:44,045 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-07 15:54:44,459 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬────────────────────┬─────────────────────┬──────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]         │
# ╞════════════════════╪════════════════════╪═════════════════════╪══════════════════════╡
# │ 3.9439089140942576 │ 0.9812213004885051 │ 0.41769461933583996 │ -0.32692019403384265 │
# └────────────────────┴────────────────────┴─────────────────────┴──────────────────────┘
# 2020-09-07 15:54:44,503 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:44,509 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌────────────────────┬────────────────────┬─────────────────────┬──────────────────────┬────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]         │ B                  │
# ╞════════════════════╪════════════════════╪═════════════════════╪══════════════════════╪════════════════════╡
# │ 3.9439089140942576 │ 0.9812213004885051 │ 0.41769461933583996 │ -0.32692019403384265 │ 101.62427870987085 │
# └────────────────────┴────────────────────┴─────────────────────┴──────────────────────┴────────────────────┘
# 2020-09-07 15:54:44,513 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_4_.txt
# 2020-09-07 15:54:46,885 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬───────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B         │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪═══════════╡
# │ 7.7 ± 1.2 │ 0.34 ± 0.11 │ 0.330 ± 0.013 │ 1.06 ± 0.21  │ 447 ± 166 │
# └───────────┴─────────────┴───────────────┴──────────────┴───────────┘
#   analysing data from multinest/sim_norm_5_.txt
# 2020-09-07 15:54:47,338 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌─────────────┬─────────────┬───────────────┬──────────────┬──────────┐
# │ A           │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞═════════════╪═════════════╪═══════════════╪══════════════╪══════════╡
# │ 4.99 ± 0.88 │ 0.50 ± 0.10 │ 0.345 ± 0.014 │ 0.80 ± 0.18  │ 178 ± 85 │
# └─────────────┴─────────────┴───────────────┴──────────────┴──────────┘
#   analysing data from multinest/sim_norm_3_.txt
# 2020-09-07 15:54:47,662 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬─────────────┬───────────────┬──────────────┬──────────┐
# │ A         │ α [MeV⁻¹]   │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞═══════════╪═════════════╪═══════════════╪══════════════╪══════════╡
# │ 5.9 ± 1.2 │ 0.57 ± 0.14 │ 0.356 ± 0.013 │ 0.61 ± 0.23  │ 155 ± 80 │
# └───────────┴─────────────┴───────────────┴──────────────┴──────────┘
# 2020-09-07 15:54:47,913 - ompy.normalizer_nld - INFO - DE results:
# ┌────────────────────┬────────────────────┬────────────────────┬──────────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │
# ╞════════════════════╪════════════════════╪════════════════════╪══════════════════════╡
# │ 7.7576358498525035 │ 0.6518881618583452 │ 0.4010205603702519 │ -0.06756344653308521 │
# └────────────────────┴────────────────────┴────────────────────┴──────────────────────┘
# 2020-09-07 15:54:47,955 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:47,961 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌────────────────────┬────────────────────┬────────────────────┬──────────────────────┬───────────────────┐
# │ A                  │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │ B                 │
# ╞════════════════════╪════════════════════╪════════════════════╪══════════════════════╪═══════════════════╡
# │ 7.7576358498525035 │ 0.6518881618583452 │ 0.4010205603702519 │ -0.06756344653308521 │ 94.68107389493855 │
# └────────────────────┴────────────────────┴────────────────────┴──────────────────────┴───────────────────┘
# 2020-09-07 15:54:47,964 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-07 15:54:48,321 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╡
# │ 4.740147905623548 │ 0.8794831561479534 │ 0.38087250141821705 │ 0.24459537396527126 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┘
# 2020-09-07 15:54:48,363 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:48,369 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬────────────────────┬─────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹]          │ T [MeV]             │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪════════════════════╪═════════════════════╪═════════════════════╪═══════════════════╡
# │ 4.740147905623548 │ 0.8794831561479534 │ 0.38087250141821705 │ 0.24459537396527126 │ 266.6703357659886 │
# └───────────────────┴────────────────────┴─────────────────────┴─────────────────────┴───────────────────┘
# 2020-09-07 15:54:48,370 - ompy.normalizer_simultan - INFO - Starting multinest:
# 2020-09-07 15:54:48,452 - ompy.normalizer_nld - INFO - DE results:
# ┌───────────────────┬───────────┬────────────────────┬─────────────────────┐
# │ A                 │ α [MeV⁻¹] │ T [MeV]            │ Eshift [MeV]        │
# ╞═══════════════════╪═══════════╪════════════════════╪═════════════════════╡
# │ 7.509067198176456 │ 0.1       │ 0.7279985474885103 │ -1.5879686924316598 │
# └───────────────────┴───────────┴────────────────────┴─────────────────────┘
# 2020-09-07 15:54:48,494 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:48,500 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌───────────────────┬───────────┬────────────────────┬─────────────────────┬───────────────────┐
# │ A                 │ α [MeV⁻¹] │ T [MeV]            │ Eshift [MeV]        │ B                 │
# ╞═══════════════════╪═══════════╪════════════════════╪═════════════════════╪═══════════════════╡
# │ 7.509067198176456 │ 0.1       │ 0.7279985474885103 │ -1.5879686924316598 │ 853.6404567337861 │
# └───────────────────┴───────────┴────────────────────┴─────────────────────┴───────────────────┘
# 2020-09-07 15:54:48,502 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_6_.txt
# 2020-09-07 15:54:50,100 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬───────────────┬───────────────┬──────────────┬──────────┐
# │ A         │ α [MeV⁻¹]     │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞═══════════╪═══════════════╪═══════════════╪══════════════╪══════════╡
# │ 9.7 ± 1.5 │ 0.348 ± 0.061 │ 0.372 ± 0.015 │ 0.44 ± 0.18  │ 198 ± 74 │
# └───────────┴───────────────┴───────────────┴──────────────┴──────────┘
# 2020-09-07 15:54:51,003 - ompy.normalizer_nld - INFO - DE results:
# ┌──────────────────┬────────────────────┬────────────────────┬──────────────────────┐
# │ A                │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │
# ╞══════════════════╪════════════════════╪════════════════════╪══════════════════════╡
# │ 7.36738414810064 │ 0.6425112906443415 │ 0.4006535864939864 │ -0.06156847931168458 │
# └──────────────────┴────────────────────┴────────────────────┴──────────────────────┘
# 2020-09-07 15:54:51,051 - ompy.normalizer_gsf - INFO - Normalizing #0
# 2020-09-07 15:54:51,057 - ompy.normalizer_simultan - INFO - DE results/initial guess:
# ┌──────────────────┬────────────────────┬────────────────────┬──────────────────────┬───────────────────┐
# │ A                │ α [MeV⁻¹]          │ T [MeV]            │ Eshift [MeV]         │ B                 │
# ╞══════════════════╪════════════════════╪════════════════════╪══════════════════════╪═══════════════════╡
# │ 7.36738414810064 │ 0.6425112906443415 │ 0.4006535864939864 │ -0.06156847931168458 │ 78.92149170430163 │
# └──────────────────┴────────────────────┴────────────────────┴──────────────────────┴───────────────────┘
# 2020-09-07 15:54:51,061 - ompy.normalizer_simultan - INFO - Starting multinest:
#   analysing data from multinest/sim_norm_7_.txt
# 2020-09-07 15:54:51,996 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬───────────────┬───────────────┬──────────────┬───────────┐
# │ A         │ α [MeV⁻¹]     │ T [MeV]       │ Eshift [MeV] │ B         │
# ╞═══════════╪═══════════════╪═══════════════╪══════════════╪═══════════╡
# │ 6.7 ± 1.3 │ 0.339 ± 0.089 │ 0.319 ± 0.011 │ 1.23 ± 0.16  │ 718 ± 250 │
# └───────────┴───────────────┴───────────────┴──────────────┴───────────┘
#   analysing data from multinest/sim_norm_9_.txt
# 2020-09-07 15:54:53,409 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌────────────┬───────────────┬───────────────┬──────────────┬──────────┐
# │ A          │ α [MeV⁻¹]     │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞════════════╪═══════════════╪═══════════════╪══════════════╪══════════╡
# │ 10.5 ± 2.0 │ 0.152 ± 0.056 │ 0.346 ± 0.011 │ 0.92 ± 0.15  │ 311 ± 95 │
# └────────────┴───────────────┴───────────────┴──────────────┴──────────┘
#   analysing data from multinest/sim_norm_8_.txt
# 2020-09-07 15:54:55,314 - ompy.normalizer_simultan - INFO - Multinest results:
# ┌───────────┬───────────────┬───────────────┬──────────────┬──────────┐
# │ A         │ α [MeV⁻¹]     │ T [MeV]       │ Eshift [MeV] │ B        │
# ╞═══════════╪═══════════════╪═══════════════╪══════════════╪══════════╡
# │ 7.2 ± 1.3 │ 0.471 ± 0.092 │ 0.350 ± 0.015 │ 0.79 ± 0.19  │ 244 ± 97 │
# └───────────┴───────────────┴───────────────┴──────────────┴──────────┘

# %%
fig, ax = plt.subplots(1,2, figsize=(figwidth*2, figheigth+3))
ensemblenorm_sim.plot(ax=ax, n_plot=5, add_figlegend=False)#, random_state=np.random.default_rng(65546645));
fig.legend(loc=9, ncol=4, frameon=True, fontsize=label_fontsize)
ax[0].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].tick_params(axis='both', labelsize=tick_labelsize)
ax[1].set_xlabel('$\gamma$-ray energy $E_\gamma$ [keV]',fontsize=label_fontsize)
ax[0].set_xlabel('Excitation energy $E_x$ [keV]',fontsize=label_fontsize)
ax[0].set_ylabel('Level Density $\\rho(E_x)$ $[MeV^{-1}]$',fontsize=label_fontsize)
ax[1].set_ylabel('$\gamma-SF$ $f(E_\gamma)\sim [MeV^{-3}]$',fontsize=label_fontsize)
fig.axes[1].tick_params(labelsize=tick_labelsize)
